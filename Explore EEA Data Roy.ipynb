# %% [markdown]
# # Improving Data Quality of the Personal Motor Insurance-associate Emissions Accounting
# # I. Exploration, Data Visualization and Data Pre-processing Report
# ## A. Introduction to the project
#
# ### Context
#
# This project is integrated into the insurance industry's sustainability initiatives, specifically addressing the tracking and reporting of "Insurance-associated Emissions" - a key performance indicator (KPI) in sustainability reporting for insurance companies.
#
# **Technical Context:**
# The project focuses on improving data quality for personal motor insurance-associated emissions accounting, which follows the Partnership for Carbon Accounting Financials (PCAF) standard. The PCAF standard provides a framework for accounting and reporting greenhouse gas (GHG) emissions associated with insurance portfolios. While reporting under this standard is voluntary, many major insurance companies have adopted it as part of their sustainability programs.
#
# The PCAF standard divides insurance-associated emissions into two groups: (1) emissions associated with commercial lines portfolios and (2) emissions associated with personal motor portfolios. Our project specifically addresses the emissions associated with personal motor portfolios.
#
# The PCAF standard defines data quality into 5 levels, with most insurance companies struggling to improve their data quality, particularly those without access to commercial data providers that can provide CO2 emission intensity data for specific vehicle models. There is also no industry standard to define what a vehicle model is, making it hard to match or look up a car's CO2 emission, even when reference data is available.
#
# **Economic Context:**
# Insurance companies are increasingly expected to report on their indirect environmental impact. Improving the quality of emissions data allows insurers to:
# 1. Enhance transparency in sustainability reporting
# 2. Better understand their portfolio's climate impact
# 3. Make data-driven decisions about risk assessment and product development
# 4. Potentially gain competitive advantage through improved sustainability metrics
# 5. Satisfy growing stakeholder demands for environmental accountability
#
# **Scientific Context:**
# The project involves analyzing vehicle emissions data from the European Environment Agency (EEA), specifically focusing on CO2 emissions and electric energy consumption intensity. This requires understanding both the NEDC (New European Driving Cycle) and WLTP (Worldwide Harmonized Light Vehicles Test Procedure) emissions testing standards. The project also aims to address the lack of industry standardization in vehicle model definitions, making it difficult to match or look up vehicle CO2 emissions even when reference data is available.
#
# ### Objectives
#
# **Main Objectives:**
# 1. Improve the data quality of Personal Motor Insurance-associated Emissions accounting by:
#    - Developing readily usable data categorized by fuel type and make/model
#    - Improving make/model classification to enable better matching
#    - Accurately accounting for both Scope 1 (vehicle's direct CO2 emissions) and Scope 2 (vehicle's electric energy consumption) emissions
# 2. Discover additional data points that can predict CO2 emissions and electric energy consumption intensity
# 3. Suggest improvements to the PCAF standard based on findings from data analysis
#
#
# ## B. Understanding and Manipulation of Data
#
# ### Framework
#
# **Dataset:**
# The primary dataset is the EEA Monitoring of CO2 emissions from passenger cars (2024) from the European Environment Agency.
#
# **Data Availability:**
# This data is freely available through the EEA's data portal (https://www.eea.europa.eu/data-and-maps/data/co2-cars-emission-20).
#
# **Dataset Volume:**
# - 80,377,293 records
# - 17.59 GB in CSV format
# - Temporal coverage: 2010-2023 (Final data only)
# - Geographical coverage: 30 EU Member States/countries
# - Contains emissions data in both NEDC and WLTP standards
# - Includes electric energy consumption intensity

# %% [markdown]
# ### Pre-processing and feature engineering

# %%
# Import necessary libraries
#import os  # For file and directory operations
import pandas as pd  # For handling CSV and Excel files
import time
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display, HTML

# %% [markdown]
# #### Load data dictionary
# More information could be found here https://circabc.europa.eu/sd/a/d9cff59f-5117-48f4-9a37-07b94027110c/MS%20Guidelines%202019

# %%
#
# Initialize Variables
file_path = "data/eea/" 
eea_data_dict = pd.read_excel(file_path + "Table-definition.xlsx", sheet_name='Sheet1', header=2)  

# Display the entire DataFrame without truncation
with pd.option_context('display.max_rows', None):
    display(eea_data_dict)
# Out:
#              Name                                         Definition  \
# 0              ID                             Identification number.
# 1              MS                                      Member state.
# 2              Mp                              Manufacturer pooling.
# 3             VFN              Vehicle family identification number.
# 4              Mh       Manufacturer name EU standard denomination .
# 5             Man                 Manufacturer name OEM declaration.
# 6             MMS       Manufacturer name MS registry denomination .
# 7             TAN                              Type approval number.
# 8               T                                              Type.
# 9              Va                                           Variant.
# 10             Ve                                           Version.
# 11             Mk                                              Make.
# 12             Cn                                   Commercial name.
# 13             Ct             Category of the vehicle type approved.
# 14             Cr                Category of the vehicle registered.
# 15         M (kg)  Mass in running order Completed/complete vehic...
# 16             Mt                                    WLTP test mass.
# 17   Enedc (g/km)                     Specific CO2 Emissions (NEDC).
# 18   Ewltp (g/km)                     Specific CO2 Emissions (WLTP).
# 19         W (mm)                                        Wheel Base.
# 20       At1 (mm)                          Axle width steering axle.
# 21       At2 (mm)                             Axle width other axle.
# 22             Ft                                         Fuel type.
# 23             Fm                                         Fuel mode.
# 24       Ec (cm3)                                   Engine capacity.
# 25        Ep (KW)                                      Engine power.
# 26      Z (Wh/km)                       Electric energy consumption.
# 27             IT  Innovative technology or group of innovative t...
# 28  Ernedc (g/km)  Emissions reduction through innovative technol...
# 29  Erwltp (g/km)  Emissions reduction through innovative technol...
# 30             De                                  Deviation factor.
# 31             Vf                               Verification factor.
# 32              R                           Total new registrations.
# 33           Year                                    Reporting year.
# 34         Status              P = Provisional data, F = Final data.
# 35   Version_file               Internal versioning of deliverables.
# 36       E (g/km)  Specific CO2 Emission. Deprecated value, only ...
# 37      Er (g/km)  Emissions reduction through innovative technol...
# 38             Zr                                    Electric range.
# 39             Dr                                 Registration date.
# 40             Fc                                  Fuel consumption.
#
#         Datatype Cardinality
# 0        integer        1..1
# 1     varchar(2)        0..1
# 2    varchar(50)        0..1
# 3    varchar(25)        0..1
# 4    varchar(50)        0..1
# 5    varchar(50)        0..1
# 6   varchar(125)        0..1
# 7    varchar(50)        0..1
# 8    varchar(25)        0..1
# 9    varchar(25)        0..1
# 10   varchar(35)        0..1
# 11   varchar(25)        0..1
# 12   varchar(50)        0..1
# 13   varchar(5)         0..1
# 14   varchar(5)         0..1
# 15       integer        0..1
# 16       integer        0..1
# 17       integer        0..1
# 18       integer        0..1
# 19       integer        0..1
# 20       integer        0..1
# 21       integer        0..1
# 22   varchar(25)        0..1
# 23   varchar(1)         0..1
# 24       integer        0..1
# 25       integer        0..1
# 26       integer        0..1
# 27   varchar(25)        0..1
# 28         float        0..1
# 29         float        0..1
# 30         float        0..1
# 31       integer        0..1
# 32       integer        0..1
# 33       integer        0..1
# 34   varchar(1)         0..1
# 35   varchar(10)        0..1
# 36         float        0..1
# 37         float        0..1
# 38       integer        0..1
# 39          date        0..1
# 40         float        0..1

# %% [markdown]
# #### Load EEA Data

# %%
# Load EEA data
countries = ['AT','BE','BG','CY','CZ','DE','DK','EE','ES','FI','FR','GB','GR','HR','HU','IE','IT','IS','LT','LU','LV','MT','NL','NO','PL','PT','RO','SE','SI','SK']

eea_df = pd.DataFrame()
for country in countries:
    start_time = time.time()  # Record the start time
    df = pd.read_csv(file_path + country + "10-23F.csv", low_memory=False)
    elapsed_time = time.time() - start_time  # Calculate elapsed time
    row_count = len(df)  # Count the number of rows in the loaded file
    print(f"Loaded {country}10-23F.csv with {row_count} rows in {elapsed_time:.2f} seconds.")  # Print elapsed time and row count
    eea_df = pd.concat([eea_df, df], ignore_index=True)
eea_df.info()
# Out:
# Loaded AT10-23F.csv with 1849653 rows in 4.31 seconds.
# Loaded BE10-23F.csv with 3487710 rows in 7.80 seconds.
# Loaded BG10-23F.csv with 225688 rows in 0.58 seconds.
# Loaded CY10-23F.csv with 94564 rows in 0.16 seconds.
# Loaded CZ10-23F.csv with 1568936 rows in 3.60 seconds.
# Loaded DE10-23F.csv with 18060636 rows in 134.23 seconds.
# Loaded DK10-23F.csv with 1409893 rows in 3.83 seconds.
# Loaded EE10-23F.csv with 192801 rows in 0.51 seconds.
# Loaded ES10-23F.csv with 6517261 rows in 15.36 seconds.
# Loaded FI10-23F.csv with 648535 rows in 1.75 seconds.
# Loaded FR10-23F.csv with 14115980 rows in 76.39 seconds.
# Loaded GB10-23F.csv with 6694100 rows in 15.08 seconds.
# Loaded GR10-23F.csv with 791779 rows in 2.09 seconds.
# Loaded HR10-23F.csv with 405701 rows in 1.08 seconds.
# Loaded HU10-23F.csv with 844047 rows in 1.88 seconds.
# Loaded IE10-23F.csv with 696541 rows in 1.56 seconds.
# Loaded IT10-23F.csv with 9787654 rows in 24.47 seconds.
# Loaded IS10-23F.csv with 84871 rows in 0.60 seconds.
# Loaded LT10-23F.csv with 226964 rows in 0.50 seconds.
# Loaded LU10-23F.csv with 374680 rows in 0.86 seconds.
# Loaded LV10-23F.csv with 128707 rows in 0.26 seconds.
# Loaded MT10-23F.csv with 89409 rows in 0.14 seconds.
# Loaded NL10-23F.csv with 2651833 rows in 5.63 seconds.
# Loaded NO10-23F.csv with 759658 rows in 1.75 seconds.
# Loaded PL10-23F.csv with 3368079 rows in 7.70 seconds.
# Loaded PT10-23F.csv with 1367394 rows in 3.16 seconds.
# Loaded RO10-23F.csv with 950863 rows in 2.18 seconds.
# Loaded SE10-23F.csv with 1941481 rows in 4.30 seconds.
# Loaded SI10-23F.csv with 435586 rows in 1.11 seconds.
# Loaded SK10-23F.csv with 606289 rows in 1.40 seconds.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80377293 entries, 0 to 80377292
# Data columns (total 40 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   ID                    int64
#  1   Country               object
#  2   VFN                   object
#  3   Mp                    object
#  4   Mh                    object
#  5   Man                   object
#  6   MMS                   object
#  7   Tan                   object
#  8   T                     object
#  9   Va                    object
#  10  Ve                    object
#  11  Mk                    object
#  12  Cn                    object
#  13  Ct                    object
#  14  Cr                    object
#  15  r                     int64
#  16  m (kg)                float64
#  17  Mt                    float64
#  18  Enedc (g/km)          float64
#  19  Ewltp (g/km)          float64
#  20  W (mm)                float64
#  21  At1 (mm)              float64
#  22  At2 (mm)              float64
#  23  Ft                    object
#  24  Fm                    object
#  25  ec (cm3)              float64
#  26  ep (KW)               float64
#  27  z (Wh/km)             float64
#  28  IT                    object
#  29  Ernedc (g/km)         float64
#  30  Erwltp (g/km)         float64
#  31  De                    float64
#  32  Vf                    float64
#  33  Status                object
#  34  year                  int64
#  35  Date of registration  object
#  36  Fuel consumption      float64
#  37  ech                   object
#  38  RLFI                  object
#  39  Electric range (km)   float64
# dtypes: float64(16), int64(3), object(21)
# memory usage: 24.0+ GB

# %% [markdown]
# #### Update data dictionary with aligned column names, Generate initial data profile and add other analysis columns
# - Country = ms
# - electtric range (km) = zr
# - fuel consumption = fc
# - date of registraion  = dr

# %%
# Replace specific rows in the 'Field Name' column of eea_data_dict
replacement_mapping = {
    'ms': 'country',
    'zr': 'electric range (km)',
    'fc' : 'fuel consumption',
    'dr' : 'date of registration'
}

# Replace the values in the 'Name' column based on the mapping
eea_data_dict['Name'] = eea_data_dict['Name'].replace(replacement_mapping)
# Drop the 'Cardinality' column only if it exists
eea_data_dict.drop(columns='Cardinality', inplace=True)
# Generate data profile for eea_df
eea_data_profile = eea_df.describe(include='all').transpose().reset_index().rename(columns={'index': 'Name'})

# Calculate the percentage of null values for each column in eea_df
null_percentage = eea_df.isnull().mean() * 100
# Calculate the number of unique values for each column in eea_df
unique_counts = eea_df.nunique()

# Ensure the index of null_percentage matches the case of the 'Name' column in eea_data_profile
null_percentage.index = null_percentage.index.str.strip().str.lower()
unique_counts.index = unique_counts.index.str.strip().str.lower()
eea_data_profile['Name'] = eea_data_profile['Name'].str.strip().str.lower()

# Map the null percentages to the "Name" column in eea_data_profile
eea_data_profile['% Null'] = eea_data_profile['Name'].map(null_percentage).apply(lambda x: f"{x:.2f}%" if pd.notnull(x) else "N/A")

# Map the unique counts to the "Name" column in eea_data_profile
eea_data_profile['Unique Counts'] = eea_data_profile['Name'].map(unique_counts).fillna(0).astype(int)


# Extract column names and data types from eea_df
eea_column_types = pd.DataFrame({
    'Name': eea_df.columns,
    'Table Data Type': eea_df.dtypes.astype(str)
})

#  Merge eea_df data profile with the data dictionary
eea_data_dict['Name'] = eea_data_dict['Name'].str.strip().str.lower()
eea_column_types['Name'] = eea_column_types['Name'].str.strip().str.lower()

data_type_and_profile = pd.merge(eea_data_profile, eea_column_types, how='outer', on='Name')
data_profile_and_dictionary = pd.merge(data_type_and_profile, eea_data_dict, how='outer', on='Name')

# Add an indicator column for the column's presence
def column_presence(row):
    if pd.notnull(row['count']) and pd.notnull(row['Definition']):
        return 'In Both'
    elif pd.isnull(row['count']) and pd.notnull(row['Definition']):
        return 'Only in Data Dictionary'
    elif pd.notnull(row['count']) and pd.isnull(row['Definition']):
        return 'Only in eea_df'
    else:
        return 'Unknown'
data_profile_and_dictionary['Presence Indicator'] = data_profile_and_dictionary.apply(column_presence, axis=1)

# Add a new column "Categorical / Quantitative" based on "Table Data Type"
data_profile_and_dictionary['Categorical / Quantitative'] = data_profile_and_dictionary['Table Data Type'].apply(
    lambda x: 'Categorical' if x == 'object' else ('Quantitative' if x in ['float64', 'int64'] else 'Unknown')
)

# Set "Categorical / Quantitative" to "Categorical" for id, year and cfn
data_profile_and_dictionary.loc[
    data_profile_and_dictionary['Name'].isin(['id', 'year', 'vf']), 
    'Categorical / Quantitative'
] = 'Categorical'

# Identify categorical columns
categorical_columns = data_profile_and_dictionary[
    data_profile_and_dictionary['Categorical / Quantitative'] == 'Categorical'
]['Name']

# Clean categorical columns: convert to uppercase and strip leading/trailing spaces
for col in categorical_columns:
    if col in eea_df.columns:  # Ensure the column exists in eea_df
        eea_df[col] = eea_df[col].astype(str).str.upper().str.strip()

# Recalculate the unique counts for all columns
new_unique_counts = eea_df.nunique().astype(int)

# Update the "Unique Values" column in data_profile_and_dictionary
data_profile_and_dictionary['Unique Counts Post Cleaning'] = data_profile_and_dictionary['Name'].map(unique_counts)


3# Sort the DataFrame by "Categorical / Quantitative" and then by "Name"
data_profile_and_dictionary = data_profile_and_dictionary.sort_values(by=['Categorical / Quantitative', 'Name'], ascending=[True, True])
# Rename columns for clarity
data_profile_and_dictionary.rename(columns={'Name': 'Field Name','Datatype': 'Datatype in Dictionary'}, inplace=True)


# Add a row number column and remove the index
data_profile_and_dictionary.insert(0, 'Row Number', range(1, len(data_profile_and_dictionary) + 1))
data_profile_and_dictionary.reset_index(drop=True, inplace=True)

data_profile_and_dictionary = data_profile_and_dictionary.reindex(columns=['Row Number', 'Field Name', 'Definition', 'Table Data Type', 'Datatype in Dictionary', 'Categorical / Quantitative', '% Null', 'Unique Counts', 'Unique Counts Post Cleaning','Presence Indicator', 'count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'])


# Display the updated DataFrame
display(data_profile_and_dictionary)
# Out:
#     Row Number            Field Name  \
# 0            1                    cn
# 1            2               country
# 2            3                    cr
# 3            4                    ct
# 4            5  date of registration
# 5            6                   ech
# 6            7                    fm
# 7            8                    ft
# 8            9                    id
# 9           10                    it
# 10          11                   man
# 11          12                    mh
# 12          13                    mk
# 13          14                   mms
# 14          15                    mp
# 15          16                  rlfi
# 16          17                status
# 17          18                     t
# 18          19                   tan
# 19          20                    va
# 20          21                    ve
# 21          22                    vf
# 22          23                   vfn
# 23          24                  year
# 24          25              at1 (mm)
# 25          26              at2 (mm)
# 26          27                    de
# 27          28              ec (cm3)
# 28          29   electric range (km)
# 29          30          enedc (g/km)
# 30          31               ep (kw)
# 31          32         ernedc (g/km)
# 32          33         erwltp (g/km)
# 33          34          ewltp (g/km)
# 34          35      fuel consumption
# 35          36                m (kg)
# 36          37                    mt
# 37          38                     r
# 38          39                w (mm)
# 39          40             z (wh/km)
# 40          41                    dr
# 41          42              e (g/km)
# 42          43             er (g/km)
# 43          44                    fc
# 44          45                    ms
# 45          46          version_file
# 46          47                    zr
#
#                                            Definition Table Data Type  \
# 0                                    Commercial name.          object
# 1                                                 NaN          object
# 2                 Category of the vehicle registered.          object
# 3              Category of the vehicle type approved.          object
# 4                                                 NaN          object
# 5                                                 NaN          object
# 6                                          Fuel mode.          object
# 7                                          Fuel type.          object
# 8                              Identification number.           int64
# 9   Innovative technology or group of innovative t...          object
# 10                 Manufacturer name OEM declaration.          object
# 11       Manufacturer name EU standard denomination .          object
# 12                                              Make.          object
# 13       Manufacturer name MS registry denomination .          object
# 14                              Manufacturer pooling.          object
# 15                                                NaN          object
# 16              P = Provisional data, F = Final data.          object
# 17                                              Type.          object
# 18                              Type approval number.          object
# 19                                           Variant.          object
# 20                                           Version.          object
# 21                               Verification factor.         float64
# 22              Vehicle family identification number.          object
# 23                                    Reporting year.           int64
# 24                          Axle width steering axle.         float64
# 25                             Axle width other axle.         float64
# 26                                  Deviation factor.         float64
# 27                                   Engine capacity.         float64
# 28                                                NaN         float64
# 29                     Specific CO2 Emissions (NEDC).         float64
# 30                                      Engine power.         float64
# 31  Emissions reduction through innovative technol...         float64
# 32  Emissions reduction through innovative technol...         float64
# 33                     Specific CO2 Emissions (WLTP).         float64
# 34                                                NaN         float64
# 35  Mass in running order Completed/complete vehic...         float64
# 36                                    WLTP test mass.         float64
# 37                           Total new registrations.           int64
# 38                                        Wheel Base.         float64
# 39                       Electric energy consumption.         float64
# 40                                 Registration date.             NaN
# 41  Specific CO2 Emission. Deprecated value, only ...             NaN
# 42  Emissions reduction through innovative technol...             NaN
# 43                                  Fuel consumption.             NaN
# 44                                      Member state.             NaN
# 45               Internal versioning of deliverables.             NaN
# 46                                    Electric range.             NaN
#
#    Datatype in Dictionary Categorical / Quantitative  % Null  Unique Counts  \
# 0             varchar(50)                Categorical   0.19%        75100.0
# 1                     NaN                Categorical   0.00%           30.0
# 2             varchar(5)                 Categorical   6.08%           10.0
# 3             varchar(5)                 Categorical   0.28%           21.0
# 4                     NaN                Categorical  64.32%         1104.0
# 5                     NaN                Categorical  93.38%           77.0
# 6             varchar(1)                 Categorical   0.10%           12.0
# 7             varchar(25)                Categorical   0.05%           58.0
# 8                 integer                Categorical   0.00%     44734088.0
# 9             varchar(25)                Categorical  64.42%          731.0
# 10            varchar(50)                Categorical   0.00%          532.0
# 11            varchar(50)                Categorical   0.00%          265.0
# 12            varchar(25)                Categorical   0.16%         1328.0
# 13           varchar(125)                Categorical  40.24%        10384.0
# 14            varchar(50)                Categorical   7.81%           52.0
# 15                    NaN                Categorical  96.17%         1455.0
# 16            varchar(1)                 Categorical   0.00%            1.0
# 17            varchar(25)                Categorical   0.10%        23080.0
# 18            varchar(50)                Categorical   0.86%        57599.0
# 19            varchar(25)                Categorical   0.27%        61500.0
# 20            varchar(35)                Categorical   0.41%       165357.0
# 21                integer                Categorical  95.24%            3.0
# 22            varchar(25)                Categorical  26.98%        12964.0
# 23                integer                Categorical   0.00%           14.0
# 24                integer               Quantitative  15.01%         1773.0
# 25                integer               Quantitative  15.81%         1518.0
# 26                  float               Quantitative  97.00%          123.0
# 27                integer               Quantitative   6.62%         2050.0
# 28                    NaN               Quantitative  91.41%          752.0
# 29                integer               Quantitative  33.42%          543.0
# 30                integer               Quantitative   8.03%          609.0
# 31                  float               Quantitative  88.33%           54.0
# 32                  float               Quantitative  76.40%          213.0
# 33                integer               Quantitative  23.63%          459.0
# 34                    NaN               Quantitative  70.30%          223.0
# 35                integer               Quantitative   0.01%         2820.0
# 36                integer               Quantitative  24.69%         2361.0
# 37                integer               Quantitative   0.00%         4947.0
# 38                integer               Quantitative  13.71%         2205.0
# 39                integer               Quantitative  89.96%          621.0
# 40                   date                    Unknown     NaN            NaN
# 41                  float                    Unknown     NaN            NaN
# 42                  float                    Unknown     NaN            NaN
# 43                  float                    Unknown     NaN            NaN
# 44             varchar(2)                    Unknown     NaN            NaN
# 45            varchar(10)                    Unknown     NaN            NaN
# 46                integer                    Unknown     NaN            NaN
#
#     Unique Counts Post Cleaning       Presence Indicator       count  \
# 0                       75100.0                  In Both    80221593
# 1                          30.0           Only in eea_df    80377293
# 2                          10.0                  In Both    75492131
# 3                          21.0                  In Both    80153247
# 4                        1104.0           Only in eea_df    28681974
# 5                          77.0           Only in eea_df     5319227
# 6                          12.0                  In Both    80292999
# 7                          58.0                  In Both    80336119
# 8                    44734088.0                  In Both  80377293.0
# 9                         731.0                  In Both    28601892
# 10                        532.0                  In Both    80376554
# 11                        265.0                  In Both    80377293
# 12                       1328.0                  In Both    80249531
# 13                      10384.0                  In Both    48035049
# 14                         52.0                  In Both    74102309
# 15                       1455.0           Only in eea_df     3076665
# 16                          1.0                  In Both    80377293
# 17                      23080.0                  In Both    80297236
# 18                      57599.0                  In Both    79685617
# 19                      61500.0                  In Both    80159031
# 20                     165357.0                  In Both    80045589
# 21                          3.0                  In Both   3823673.0
# 22                      12964.0                  In Both    58689497
# 23                         14.0                  In Both  80377293.0
# 24                       1773.0                  In Both  68314348.0
# 25                       1518.0                  In Both  67672263.0
# 26                        123.0                  In Both   2408796.0
# 27                       2050.0                  In Both  75057556.0
# 28                        752.0           Only in eea_df   6905366.0
# 29                        543.0                  In Both  53515953.0
# 30                        609.0                  In Both  73926361.0
# 31                         54.0                  In Both   9382424.0
# 32                        213.0                  In Both  18969057.0
# 33                        459.0                  In Both  61383725.0
# 34                        223.0           Only in eea_df  23873152.0
# 35                       2820.0                  In Both  80366778.0
# 36                       2361.0                  In Both  60528576.0
# 37                       4947.0                  In Both  80377293.0
# 38                       2205.0                  In Both  69357159.0
# 39                        621.0                  In Both   8069067.0
# 40                          NaN  Only in Data Dictionary         NaN
# 41                          NaN  Only in Data Dictionary         NaN
# 42                          NaN  Only in Data Dictionary         NaN
# 43                          NaN  Only in Data Dictionary         NaN
# 44                          NaN  Only in Data Dictionary         NaN
# 45                          NaN  Only in Data Dictionary         NaN
# 46                          NaN  Only in Data Dictionary         NaN
#
#                mean              std     min        25%         50%  \
# 0               NaN              NaN     NaN        NaN         NaN
# 1               NaN              NaN     NaN        NaN         NaN
# 2               NaN              NaN     NaN        NaN         NaN
# 3               NaN              NaN     NaN        NaN         NaN
# 4               NaN              NaN     NaN        NaN         NaN
# 5               NaN              NaN     NaN        NaN         NaN
# 6               NaN              NaN     NaN        NaN         NaN
# 7               NaN              NaN     NaN        NaN         NaN
# 8   36025255.219891  43883004.596267     1.0  4103072.0  10517259.0
# 9               NaN              NaN     NaN        NaN         NaN
# 10              NaN              NaN     NaN        NaN         NaN
# 11              NaN              NaN     NaN        NaN         NaN
# 12              NaN              NaN     NaN        NaN         NaN
# 13              NaN              NaN     NaN        NaN         NaN
# 14              NaN              NaN     NaN        NaN         NaN
# 15              NaN              NaN     NaN        NaN         NaN
# 16              NaN              NaN     NaN        NaN         NaN
# 17              NaN              NaN     NaN        NaN         NaN
# 18              NaN              NaN     NaN        NaN         NaN
# 19              NaN              NaN     NaN        NaN         NaN
# 20              NaN              NaN     NaN        NaN         NaN
# 21         0.007219         0.084665     0.0        0.0         0.0
# 22              NaN              NaN     NaN        NaN         NaN
# 23      2019.771564         2.219177  2010.0     2018.0      2020.0
# 24      1556.383152       124.924099     0.0     1509.0      1550.0
# 25      1544.214327        64.908789     0.0     1504.0      1547.0
# 26         0.010168         0.021749   -0.24     -0.001       0.014
# 27      1550.800786       518.299377     0.0     1199.0      1498.0
# 28       255.269392       188.942506    10.0       62.0       237.0
# 29       112.155125        42.503402     0.0      102.0       115.0
# 30       103.294795        51.350621     0.0       72.0        92.0
# 31         1.768928         0.755212     0.0        1.2         1.5
# 32         1.487726         0.503496     0.0       1.03        1.58
# 33        125.63788        52.698537     0.0      118.0       133.0
# 34          5.39952         1.727887     0.1        4.9         5.4
# 35      1456.501099       322.105915     1.0     1229.0      1395.0
# 36      1600.572551       347.648153   135.0     1350.0      1542.0
# 37         2.211052         47.28428     1.0        1.0         1.0
# 38       2640.39423       206.974511     0.0     2552.0      2640.0
# 39       172.041469        39.979303     1.0      153.0       165.0
# 40              NaN              NaN     NaN        NaN         NaN
# 41              NaN              NaN     NaN        NaN         NaN
# 42              NaN              NaN     NaN        NaN         NaN
# 43              NaN              NaN     NaN        NaN         NaN
# 44              NaN              NaN     NaN        NaN         NaN
# 45              NaN              NaN     NaN        NaN         NaN
# 46              NaN              NaN     NaN        NaN         NaN
#
#            75%          max
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
# 5          NaN          NaN
# 6          NaN          NaN
# 7          NaN          NaN
# 8   65122403.0  162072500.0
# 9          NaN          NaN
# 10         NaN          NaN
# 11         NaN          NaN
# 12         NaN          NaN
# 13         NaN          NaN
# 14         NaN          NaN
# 15         NaN          NaN
# 16         NaN          NaN
# 17         NaN          NaN
# 18         NaN          NaN
# 19         NaN          NaN
# 20         NaN          NaN
# 21         0.0          2.0
# 22         NaN          NaN
# 23      2022.0       2023.0
# 24      1580.0      15851.0
# 25      1580.0      15830.0
# 26       0.027          4.8
# 27      1968.0      84638.0
# 28       431.0        883.0
# 29       131.0        985.0
# 30       112.0       1770.0
# 31         2.3          6.8
# 32        1.94          4.6
# 33       151.0       2810.0
# 34         6.1         25.2
# 35      1616.0       9825.0
# 36      1782.0       6542.0
# 37         1.0      59092.0
# 38      2720.0       6100.0
# 39       181.0       1754.0
# 40         NaN          NaN
# 41         NaN          NaN
# 42         NaN          NaN
# 43         NaN          NaN
# 44         NaN          NaN
# 45         NaN          NaN
# 46         NaN          NaN

# %%
# Add new analysis columns for further data profiling
data_profile_and_dictionary['Unique Counts Post Cleaning'] = None
data_profile_and_dictionary['Distribution'] = None
data_profile_and_dictionary['Deleting?'] = None
data_profile_and_dictionary['Why Deleting?'] = None
data_profile_and_dictionary['Comments'] = None

additional_columns_cat = ['Unique Counts Post Cleaning', 'Distribution', 'Deleting?', 'Why Deleting?', 'Comments']
additional_columns_noncat = ['Unique Counts Post Cleaning', 'Deleting?', 'Why Deleting?', 'Comments']

categorical_columns = ['Row Number', 'Field Name', 'Definition', 'Table Data Type', 'Datatype in Dictionary', 'Categorical / Quantitative', '% Null', 'Unique Counts', 'Presence Indicator'] + additional_columns_cat
noncategorical_columns = ['Row Number', 'Field Name', 'Definition', 'Table Data Type', 'Datatype in Dictionary', 'Categorical / Quantitative', '% Null', 'Deleting?', 'Why Deleting?', 'Comments', 'Presence Indicator', 'count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'] + additional_columns_noncat

eea_df.columns = eea_df.columns.str.strip().str.lower()

# %% [markdown]
# #### Individual column checks

# %% [markdown]
# ##### 1. Commerical Name (Cn)

# %%
current_columns = ['cn']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])

display(eea_df[current_columns].value_counts())
# Out:
#    Row Number Field Name        Definition Table Data Type  \
# 0           1         cn  Commercial name.          object
#
#   Datatype in Dictionary Categorical / Quantitative % Null  Unique Counts  \
# 0            varchar(50)                Categorical  0.19%        75100.0
#
#   Presence Indicator Unique Counts Post Cleaning Distribution Deleting?  \
# 0            In Both                        None         None      None
#
#   Why Deleting? Comments
# 0          None     None
# cn
# CLIO                     1705408
# GOLF                     1548858
# 208                      1334442
# SANDERO                  1296609
# C3                       1079465
#                           ...
# BENZ 211 E350 4MATIC           1
# E 220 CDI BE 5DR AUTO          1
# BENZ A170CDI                   1
# BENZ C 200 CDI                 1
# ‘‘                             1
# Name: count, Length: 75100, dtype: int64

# %%
for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Potential Target or Feature. Further cleaning needed based on domain knowledge.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#    Row Number Field Name        Definition Table Data Type  \
# 0           1         cn  Commercial name.          object
#
#   Datatype in Dictionary Categorical / Quantitative % Null  Unique Counts  \
# 0            varchar(50)                Categorical  0.19%        75100.0
#
#   Presence Indicator Unique Counts Post Cleaning  \
# 0            In Both                        None
#
#                                         Distribution Deleting? Why Deleting?  \
# 0  GOLF, GOLF SPORTSVAN, Q7, Q7 E-TRON, SQ7, Q5, ...        No           N/A
#
#                                             Comments
# 0  Potential Target or Feature. Further cleaning ...

# %% [markdown]
# ##### 2. Country / MS (member state)

# %%
current_columns = ['country']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])

eea_df['country'] = eea_df['country'].str.strip().str.upper()
new_unique_count = eea_df['country'].nunique()

print('Unique Country after cleaning:', int(new_unique_count))
display(eea_df[current_columns].value_counts())
# Out:
#    Row Number Field Name Definition Table Data Type Datatype in Dictionary  \
# 1           2    country        NaN          object                    NaN
#
#   Categorical / Quantitative % Null  Unique Counts Presence Indicator  \
# 1                Categorical  0.00%           30.0     Only in eea_df
#
#   Unique Counts Post Cleaning Distribution Deleting? Why Deleting? Comments
# 1                        None         None      None          None     None
# Unique Country after cleaning: 30
# country
# DE         18060636
# FR         14115980
# IT          9787654
# GB          6694100
# ES          6517261
# BE          3487710
# PL          3368079
# NL          2651833
# SE          1941481
# AT          1849653
# CZ          1568936
# DK          1409893
# PT          1367394
# RO           950863
# HU           844047
# GR           791779
# NO           759658
# IE           696541
# FI           648535
# SK           606289
# SI           435586
# HR           405701
# LU           374680
# LT           226964
# BG           225688
# EE           192801
# LV           128707
# CY            94564
# MT            89409
# IS            84871
# Name: count, dtype: int64

# %%
# Update Analysis fields
for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'

    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Feature candidate. No missing and rouge values'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#    Row Number Field Name Definition Table Data Type Datatype in Dictionary  \
# 1           2    country        NaN          object                    NaN
#
#   Categorical / Quantitative % Null  Unique Counts Presence Indicator  \
# 1                Categorical  0.00%           30.0     Only in eea_df
#
#   Unique Counts Post Cleaning                                 Distribution  \
# 1                        None  AT, BE, BG, CY, CZ, DE, DK, EE, ES, FI, ...
#
#   Deleting? Why Deleting?                                        Comments
# 1        No           N/A  Feature candidate. No missing and rouge values

# %% [markdown]
# ##### 3. Category of the vehicle registered (Cr)
# The vehicle category registered is indicated in point J of Part I of the Registration Certificate.
# It is the vehicle category registered that determines whether a vehicle is considered as
# M1 or N1 for the purpose of the CO2 emission standards

# %%
current_columns = ['cr']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
display(eea_df['cr'].value_counts())
# Out:
#    Row Number Field Name                           Definition Table Data Type  \
# 2           3         cr  Category of the vehicle registered.          object
#
#   Datatype in Dictionary Categorical / Quantitative % Null  Unique Counts  \
# 2            varchar(5)                 Categorical  6.08%           10.0
#
#   Presence Indicator Unique Counts Post Cleaning Distribution Deleting?  \
# 2            In Both                        None         None      None
#
#   Why Deleting? Comments
# 2          None     None
# cr
# M1      72513826
# M1G      2437332
# M1        524394
# M1          9890
#             4847
# M1G         1211
# m1           595
# M1S           22
# N1G           13
# N1             1
# Name: count, dtype: int64

# %% [markdown]
# Category of the vehicle registered (Cr) data analysis
# - indicator if the vehicle is car or
# - good data availability
# - to be further cleaned
# - null values to ba assinge as cars

# %%
for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'

    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Potential feature. Further analysis needed to determine relevance.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#    Row Number Field Name                           Definition Table Data Type  \
# 2           3         cr  Category of the vehicle registered.          object
#
#   Datatype in Dictionary Categorical / Quantitative % Null  Unique Counts  \
# 2            varchar(5)                 Categorical  6.08%           10.0
#
#   Presence Indicator Unique Counts Post Cleaning  \
# 2            In Both                        None
#
#                                         Distribution Deleting? Why Deleting?  \
# 2  nan, M1, M1G, M1 , N1, N1G,  , M1S, m1, M1  , ...        No           N/A
#
#                                             Comments
# 2  Potential feature. Further analysis needed to ...

# %% [markdown]
# ##### 4. Category of the vehicle type approved (Ct)
# The vehicle category type approved (M1, N1 etc.) is set out in section 0.4 of the certificate of
# conformity. It should be noted that a vehicle may be type approved in one category and
# registered in another.
#  basis for categoriztion for CO2 emission reporing

# %%
current_columns = ['ct']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
eea_df['ct'].value_counts()
# Out:
#    Row Number Field Name                              Definition  \
# 3           4         ct  Category of the vehicle type approved.
#
#   Table Data Type Datatype in Dictionary Categorical / Quantitative % Null  \
# 3          object            varchar(5)                 Categorical  0.28%
#
#    Unique Counts Presence Indicator Unique Counts Post Cleaning Distribution  \
# 3           21.0            In Both                        None         None
#
#   Deleting? Why Deleting? Comments
# 3      None          None     None
# ct
# M1            77043879
# M1G            2693986
# M1              383797
# M1                9255
# N1                9247
# m1                8920
# M1                3062
# M1G                732
# N1G                143
# N2                 141
# N3                  27
# N1                  26
# N2G                 11
# L                    7
#                      6
# M1S                  3
# M2                   1
#                      1
# N3G                  1
# MASTER               1
# N1 inc               1
# Name: count, dtype: int64

# %% [markdown]
# Category of the vehicle type approved (Ct) data analysis
# - indicator if the vehicle is car or van or other
# - good data availability
# - to be dropped as cr is the

# %%
# Update Analysis fields
for current_column in current_columns:
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'

    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'Yes'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'As per data dictionary: CR should be used for CO2 analysis.'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'To be deleted before analysis.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#    Row Number Field Name                              Definition  \
# 3           4         ct  Category of the vehicle type approved.
#
#   Table Data Type Datatype in Dictionary Categorical / Quantitative % Null  \
# 3          object            varchar(5)                 Categorical  0.28%
#
#    Unique Counts Presence Indicator Unique Counts Post Cleaning  \
# 3           21.0            In Both                        None
#
#                                         Distribution Deleting?  \
# 3  M1, M1G, N1G, N1, nan, M1        ,   , N2, M1 ...       Yes
#
#                                        Why Deleting?  \
# 3  As per data dictionary: CR should be used for ...
#
#                          Comments
# 3  To be deleted before analysis.

# %% [markdown]
# ##### 5. Date of Registration

# %%
current_columns = ['date of registration']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])

display(eea_df['date of registration'].value_counts())
# Out:
#    Row Number            Field Name Definition Table Data Type  \
# 4           5  date of registration        NaN          object
#
#   Datatype in Dictionary Categorical / Quantitative  % Null  Unique Counts  \
# 4                    NaN                Categorical  64.32%         1104.0
#
#   Presence Indicator Unique Counts Post Cleaning Distribution Deleting?  \
# 4     Only in eea_df                        None         None      None
#
#   Why Deleting? Comments
# 4          None     None
# date of registration
# 2023-06-30    104223
# 2023-04-28    103823
# 2023-05-31    102863
# 2021-01-01    102575
# 2023-03-31    101549
#                ...
# 2016-02-12         1
# 2015-05-04         1
# 2013-03-19         1
# 2017-04-19         1
# 2014-09-30         1
# Name: count, Length: 1104, dtype: int64

# %%
# Update Analysis fields

for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'

    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'Yes'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'Not interesting for analysis. Year granularity is sufficient.'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'To be deleted before analysis.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#    Row Number            Field Name Definition Table Data Type  \
# 4           5  date of registration        NaN          object
#
#   Datatype in Dictionary Categorical / Quantitative  % Null  Unique Counts  \
# 4                    NaN                Categorical  64.32%         1104.0
#
#   Presence Indicator Unique Counts Post Cleaning  \
# 4     Only in eea_df                        None
#
#                                         Distribution Deleting?  \
# 4  nan, 2021-01-01, 2021-04-07, 2021-05-28, 2021-...       Yes
#
#                                        Why Deleting?  \
# 4  Not interesting for analysis. Year granularity...
#
#                          Comments
# 4  To be deleted before analysis.

# %% [markdown]
# ##### 6 ech

# %%
current_columns = ['ech']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])

display(eea_df[current_columns].value_counts())
# Out:
#    Row Number Field Name Definition Table Data Type Datatype in Dictionary  \
# 5           6        ech        NaN          object                    NaN
#
#   Categorical / Quantitative  % Null  Unique Counts Presence Indicator  \
# 5                Categorical  93.38%           77.0     Only in eea_df
#
#   Unique Counts Post Cleaning Distribution Deleting? Why Deleting? Comments
# 5                        None         None      None          None     None
# ech
# NAN          75058066
# EURO 6 AP     1611507
# 6AP           1068766
# AX             648722
# EURO 6AP       614187
#                ...
# EURO 6 CI           1
# VI D                1
# 5 (G)               1
# EURO 6 DG           1
# ZX                  1
# Name: count, Length: 67, dtype: int64

# %%
for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'

    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'Yes'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'Mostly Empty. Not found in data dictionary.'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'To be deleted before analysis.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#    Row Number Field Name Definition Table Data Type Datatype in Dictionary  \
# 5           6        ech        NaN          object                    NaN
#
#   Categorical / Quantitative  % Null  Unique Counts Presence Indicator  \
# 5                Categorical  93.38%           77.0     Only in eea_df
#
#   Unique Counts Post Cleaning  \
# 5                        None
#
#                                         Distribution Deleting?  \
# 5  NAN, 6AP, 715/2007*2018/1832AP, EURO 6 AP, AP,...       Yes
#
#                                  Why Deleting?                        Comments
# 5  Mostly Empty. Not found in data dictionary.  To be deleted before analysis.

# %% [markdown]
# #####  7 Fuel Mode
# Reference: https://circabc.europa.eu/sd/a/d9cff59f-5117-48f4-9a37-07b94027110c/MS%20Guidelines%202019
#
# For the fuel mode the permitted entries are:
# - "M" for mono-fuel vehicles, i.e. vehicles able to run on only one fuel, either petrol,
# diesel, LPG, natural gas (NG) or hydrogen. The latter category also covers Fuel Cell
# electric vehicles, i.e. vehicles equipped with a powertrain containing exclusively fuel
# cell(s) and electric machine(s) as propulsion energy converter(s).
# - "B" for bi-fuel vehicles, i.e. vehicles with two separate fuel storage systems, which are
# designed to run primarily on only one fuel at a time. This covers vehicles that can run on
# petrol and either LPG, NG/biomethane or hydrogen.
# - “F” for flex-fuel vehicles, i.e. vehicles with one fuel storage system that can run on
# different mixtures of two or more fuels; this concerns more specifically ‘flex fuel ethanol
# vehicles’, which can run on petrol or a mixture of petrol and ethanol up to an 85 per cent
# ethanol blend (E85);
# - "E" for battery electric vehicles (BEV), i.e. "pure" electric vehicles (NOT hybrid
# vehicles). These vehicles can be identified using section 23 of the certificate of
# conformity.
# - “P” for Off vehicle charging hybrid electric vehicles (OVC-HEV), i.e. plug-in hybrid
# vehicles. These vehicles can be identified using section 23.1 of the certificate of
# conformity. Their weighted average CO2 values are specified in section 49.1. (NEDC)
# and section 49.4 (WLTP) of the certificate of conformity.
# - “H” for Not-Off vehicle charging hybrid electric vehicles (NOVC-HEV). These vehicles
# can be identified using section 23.1 of the certificate of conformity. They cannot take
# electric energy from external sources and are only fuelled with one of fuel types
# specified in section 26 of the CoC. The CO2 values for that fuel shall be reported.

# %%
current_columns = ['fm']   
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
display(eea_df['fm'].value_counts())
# Out:
#    Row Number Field Name  Definition Table Data Type Datatype in Dictionary  \
# 6           7         fm  Fuel mode.          object            varchar(1)
#
#   Categorical / Quantitative % Null  Unique Counts Presence Indicator  \
# 6                Categorical  0.10%           12.0            In Both
#
#   Unique Counts Post Cleaning Distribution Deleting? Why Deleting? Comments
# 6                        None         None      None          None     None
# fm
# M                            61185269
# H                             8968677
# E                             5214918
# P                             3477842
# B                             1390082
# F                               47688
# b                                4616
# na                               2453
# M                                 702
# n                                 700
# 2                                  51
# Alimentazione Sconosciuta           1
# Name: count, dtype: int64

# %% [markdown]
# Fuel Model Data Analysis
# Fuel mode can be used to correctly identify electric vehicles (EVs) and plug-in hybrid electric vehicles (PHEVs) and other hybrid types in the dataset.

# %%
# Update Analysis fields
for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'

    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Initial cleaning (case, trim) done. From 12 to 10 unique values. Further cleaning may be needed based on domain knowledge'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#    Row Number Field Name  Definition Table Data Type Datatype in Dictionary  \
# 6           7         fm  Fuel mode.          object            varchar(1)
#
#   Categorical / Quantitative % Null  Unique Counts Presence Indicator  \
# 6                Categorical  0.10%           12.0            In Both
#
#   Unique Counts Post Cleaning                          Distribution Deleting?  \
# 6                        None  M, E, B, H, P, F, nan, 2, na, n, ...        No
#
#   Why Deleting?                                           Comments
# 6           N/A  Initial cleaning (case, trim) done. From 12 to...

# %% [markdown]
# ##### 8 Fuel Type

# %%
current_columns = ['ft']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])

display(eea_df['ft'].value_counts())
# Out:
#    Row Number Field Name  Definition Table Data Type Datatype in Dictionary  \
# 7           8         ft  Fuel type.          object            varchar(25)
#
#   Categorical / Quantitative % Null  Unique Counts Presence Indicator  \
# 7                Categorical  0.05%           58.0            In Both
#
#   Unique Counts Post Cleaning Distribution Deleting? Why Deleting? Comments
# 7                        None         None      None          None     None
# ft
# petrol                       21144786
# PETROL                       18726944
# DIESEL                        9552983
# diesel                        8798562
# Petrol                        6440503
# Diesel                        5058667
# electric                      3292123
# petrol/electric               1848791
# ELECTRIC                      1813763
# PETROL/ELECTRIC               1524300
# lpg                            706656
# LPG                            604361
# NG                             148591
# Electric                       113943
# Petrol/Electric                100336
# DIESEL/ELECTRIC                 99761
# e85                             92520
# diesel/electric                 85637
# ng                              76115
# NG-BIOMETHANE                   21624
# ng-biomethane                   18135
# E85                             15214
# NG-biomethane                   12601
# DIESEL                           9441
# PETROL                           4649
# Diesel/Electric                  4501
# unknown                          2708
#                                  2679
# Petrol-electric                  2524
# CNG                              2476
# hydrogen                         2235
# HYDROGEN                         1904
# PETROL-ELECTRIC                  1429
# petrol-electric                  1394
# Petrol-Electric                   906
# Diesel-electric                   384
# Diesel-Electric                   308
# diesel-electric                   284
# LPG                               269
# UNKNOWN                           213
# Electric                          163
# NG-biomethane                     127
# Hydrogen                          119
# Petrol                            114
# Diesel/electric                    96
# Biodiesel                          90
# NG-Biomethane                      80
# HYBRID/PETROL/E                    44
# DIESEL-ELECTRIC                    25
# PETROL PHEV                        20
# OTHER                               8
# petrol                              3
# BIODIESEL                           3
# GNL                                 2
# Other                               2
# Petrol-Gas                          1
# NG_biomethane                       1
# PETROL                              1
# Name: count, dtype: int64

# %% [markdown]
# Fuel Type Analysis
# - good data availability
# - after making case neutral and stripping leading/trailing spaces
# - further data cleaning and grouping is needed

# %%
# Update Analysis fields

for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'

    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Initial cleaning (case, trim) done, 58 to 22 unique values after initial cleaning. Further cleaning may be needed based on domain knowledge'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#    Row Number Field Name  Definition Table Data Type Datatype in Dictionary  \
# 7           8         ft  Fuel type.          object            varchar(25)
#
#   Categorical / Quantitative % Null  Unique Counts Presence Indicator  \
# 7                Categorical  0.05%           58.0            In Both
#
#   Unique Counts Post Cleaning  \
# 7                        None
#
#                                         Distribution Deleting? Why Deleting?  \
# 7  Petrol, Electric, Diesel, Diesel-electric, pet...        No           N/A
#
#                                             Comments
# 7  Initial cleaning (case, trim) done, 58 to 22 u...

# %% [markdown]
# ##### 9 ID
# Record Identifier, not useful for analysis.

# %%
current_columns = ['id']
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'Yes'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'Record Identifier, not useful for analysis.'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'To be deleted before analysis.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#    Row Number Field Name              Definition Table Data Type  \
# 8           9         id  Identification number.           int64
#
#   Datatype in Dictionary Categorical / Quantitative % Null  Unique Counts  \
# 8                integer                Categorical  0.00%     44734088.0
#
#   Presence Indicator Unique Counts Post Cleaning Distribution Deleting?  \
# 8            In Both                        None         None       Yes
#
#                                  Why Deleting?                        Comments
# 8  Record Identifier, not useful for analysis.  To be deleted before analysis.

# %% [markdown]
# ##### 10 it  Innovative technology

# %%
current_columns = ['it']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
 
display(eea_df['it'].value_counts())
# Out:
#    Row Number Field Name                                         Definition  \
# 9          10         it  Innovative technology or group of innovative t...
#
#   Table Data Type Datatype in Dictionary Categorical / Quantitative  % Null  \
# 9          object            varchar(25)                Categorical  64.42%
#
#    Unique Counts Presence Indicator Unique Counts Post Cleaning Distribution  \
# 9          731.0            In Both                        None         None
#
#   Deleting? Why Deleting? Comments
# 9      None          None     None
# it
# e2 28 29              1855016
# e9 29 37              1426978
# e1 29                 1241945
# E2 17                 1217455
# e2 29 37              1165862
#                        ...
# e24*32/37                   1
# e24*37                      1
# E24 10 E24 3 E24 9          1
# E24 10. E24 2               1
#  e5  e5 29                  1
# Name: count, Length: 731, dtype: int64

# %%
for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'

    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Initial cleaning (case, trim) done, 731 to 490 unique values after initial cleaning. Further cleaning may be needed based on domain knowledge'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#    Row Number Field Name                                         Definition  \
# 9          10         it  Innovative technology or group of innovative t...
#
#   Table Data Type Datatype in Dictionary Categorical / Quantitative  % Null  \
# 9          object            varchar(25)                Categorical  64.42%
#
#    Unique Counts Presence Indicator Unique Counts Post Cleaning  \
# 9          731.0            In Both                        None
#
#                                         Distribution Deleting? Why Deleting?  \
# 9  nan, e1 9, E2 17, E2 19, E2 17 19, e13 19, e13...        No           N/A
#
#                                             Comments
# 9  Initial cleaning (case, trim) done, 731 to 490...

# %% [markdown]
# ##### 11 -15 Manufacturer fields 'it' 'man','mh','mk','mms','mp'

# %%
current_columns = ['man','mh','mk','mms','mp']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
display(eea_df[current_columns].value_counts())
# Out:
#     Row Number Field Name                                    Definition  \
# 10          11        man            Manufacturer name OEM declaration.
# 11          12         mh  Manufacturer name EU standard denomination .
# 12          13         mk                                         Make.
# 13          14        mms  Manufacturer name MS registry denomination .
# 14          15         mp                         Manufacturer pooling.
#
#    Table Data Type Datatype in Dictionary Categorical / Quantitative  % Null  \
# 10          object            varchar(50)                Categorical   0.00%
# 11          object            varchar(50)                Categorical   0.00%
# 12          object            varchar(25)                Categorical   0.16%
# 13          object           varchar(125)                Categorical  40.24%
# 14          object            varchar(50)                Categorical   7.81%
#
#     Unique Counts Presence Indicator Unique Counts Post Cleaning Distribution  \
# 10          532.0            In Both                        None         None
# 11          265.0            In Both                        None         None
# 12         1328.0            In Both                        None         None
# 13        10384.0            In Both                        None         None
# 14           52.0            In Both                        None         None
#
#    Deleting? Why Deleting? Comments
# 10      None          None     None
# 11      None          None     None
# 12      None          None     None
# 13      None          None     None
# 14      None          None     None
# man                  mh                   mk          mms                            mp
# AUTOMOBILES PEUGEOT  AUTOMOBILES PEUGEOT  PEUGEOT     AUTOMOBILES PEUGEOT            PSA-OPEL       1769332
# RENAULT SAS          RENAULT              RENAULT     RENAULT SAS                    RENAULT        1606428
# VOLKSWAGEN AG        VOLKSWAGEN           VOLKSWAGEN  VOLKSWAGEN AG                  VW GROUP PC    1437187
# AUTOMOBILES CITROEN  AUTOMOBILES CITROEN  CITROEN     AUTOMOBILES CITROEN            PSA-OPEL       1188012
# AUDI AG              AUDI AG              AUDI        AUDI                           VW GROUP PC     873933
#                                                                                                      ...
# LAND ROVER           LAND ROVER           LAND ROVER  LAND ROVER LA S4AA2F B5O1      JLT POOL             1
#                                                       LAND ROVER LA S4AA2F B5O2      JLT POOL             1
#                                                                                      TJL                  1
#                                                       LAND ROVER LA S4AA2F B7D1      JLT POOL             1
# FORD-WERKE GMBH      FORD-WERKE GMBH      FORD        FORD W GMBH FDA6 H9FB2A D9CCA  FORD POOL            1
# Name: count, Length: 7401, dtype: int64

# %% [markdown]
# Manufacturer Fields
# - the fields can be merged and create a single field universal field for manufacturers

# %%
for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'

    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further cleaning/merging with other Manufacturer fields to be done based on domain knowledge.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#     Row Number Field Name                                    Definition  \
# 10          11        man            Manufacturer name OEM declaration.
# 11          12         mh  Manufacturer name EU standard denomination .
# 12          13         mk                                         Make.
# 13          14        mms  Manufacturer name MS registry denomination .
# 14          15         mp                         Manufacturer pooling.
#
#    Table Data Type Datatype in Dictionary Categorical / Quantitative  % Null  \
# 10          object            varchar(50)                Categorical   0.00%
# 11          object            varchar(50)                Categorical   0.00%
# 12          object            varchar(25)                Categorical   0.16%
# 13          object           varchar(125)                Categorical  40.24%
# 14          object            varchar(50)                Categorical   7.81%
#
#     Unique Counts Presence Indicator Unique Counts Post Cleaning  \
# 10          532.0            In Both                        None
# 11          265.0            In Both                        None
# 12         1328.0            In Both                        None
# 13        10384.0            In Both                        None
# 14           52.0            In Both                        None
#
#                                          Distribution Deleting? Why Deleting?  \
# 10  VOLKSWAGEN AG, AUDI AG, SEAT SA, VOLVO CAR COR...        No           N/A
# 11  VOLKSWAGEN, AUDI AG, SEAT, VOLVO, DAIMLER AG, ...        No           N/A
# 12  VOLKSWAGEN, VW, AUDI, SEAT, VOLVO, MERCEDES-BE...        No           N/A
# 13  VOLKSWAGEN AG, AUDI AG DE-85045 INGOLSTADT, SE...        No           N/A
# 14  VW GROUP PC, nan, DAIMLER AG, PSA-OPEL, FCA-TE...        No           N/A
#
#                                              Comments
# 10  Further cleaning/merging with other Manufactur...
# 11  Further cleaning/merging with other Manufactur...
# 12  Further cleaning/merging with other Manufactur...
# 13  Further cleaning/merging with other Manufactur...
# 14  Further cleaning/merging with other Manufactur...

# %% [markdown]
# ##### 16 rlfi

# %%
current_columns = ['rlfi']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])

display(eea_df[current_columns].value_counts())
# Out:
#     Row Number Field Name Definition Table Data Type Datatype in Dictionary  \
# 15          16       rlfi        NaN          object                    NaN
#
#    Categorical / Quantitative  % Null  Unique Counts Presence Indicator  \
# 15                Categorical  96.17%         1455.0     Only in eea_df
#
#    Unique Counts Post Cleaning Distribution Deleting? Why Deleting? Comments
# 15                        None         None      None          None     None
# rlfi
# N.A.                        158027
# RL-DQ200_7F_17_012-WVW-1    131757
# RL-DQ381_7F_17_021-WVW-1     59294
# RL-DQ381_7F_19_001-WVW-1     54220
# RL-EQ310_1P_21_003-WVW-1     51494
#                              ...
# RL-DQ381_7F_23_005-WVW           1
# RL-991II2AT70ZZZ00-WP0-1         1
# RL-MQ500Z6F_19_202-WVN-1         1
# RL-13_KE19_02-JMZ-1              1
# RL-0015-SCF-2                    1
# Name: count, Length: 1455, dtype: int64

# %%
for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'

    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'Yes'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'Mostly Empty. Not found in data dictionary.'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'To be deleted before analysis.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#     Row Number Field Name Definition Table Data Type Datatype in Dictionary  \
# 15          16       rlfi        NaN          object                    NaN
#
#    Categorical / Quantitative  % Null  Unique Counts Presence Indicator  \
# 15                Categorical  96.17%         1455.0     Only in eea_df
#
#    Unique Counts Post Cleaning  \
# 15                        None
#
#                                          Distribution Deleting?  \
# 15  nan, RL-DQ500Z7A_20_201-WVN-1, RL-J12ADZAYA_00...       Yes
#
#                                   Why Deleting?  \
# 15  Mostly Empty. Not found in data dictionary.
#
#                           Comments
# 15  To be deleted before analysis.

# %% [markdown]
# ##### 17. Status
# Not relevant moving forward, all records downloaded are are final status

# %%
##17 Status
current_columns = ['status']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#     Row Number Field Name                             Definition  \
# 16          17     status  P = Provisional data, F = Final data.
#
#    Table Data Type Datatype in Dictionary Categorical / Quantitative % Null  \
# 16          object            varchar(1)                 Categorical  0.00%
#
#     Unique Counts Presence Indicator Unique Counts Post Cleaning Distribution  \
# 16            1.0            In Both                        None         None
#
#    Deleting? Why Deleting? Comments
# 16      None          None     None

# %%
for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'

    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'Yes'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'All reecords are final'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'To be deleted before analysis.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#     Row Number Field Name                             Definition  \
# 16          17     status  P = Provisional data, F = Final data.
#
#    Table Data Type Datatype in Dictionary Categorical / Quantitative % Null  \
# 16          object            varchar(1)                 Categorical  0.00%
#
#     Unique Counts Presence Indicator Unique Counts Post Cleaning Distribution  \
# 16            1.0            In Both                        None            F
#
#    Deleting?           Why Deleting?                        Comments
# 16       Yes  All reecords are final  To be deleted before analysis.

# %% [markdown]
# ##### 18. Type (T), 20. Variant (Va) and 21. Version (Ve)
#
# https://circabc.europa.eu/sd/a/d9cff59f-5117-48f4-9a37-07b94027110c/MS%20Guidelines%202019
# These three parameters allow identifying the data relating to the same version of the vehicle
# delivered from different Member States. A correct recording of the combined TVV code is
# important for allowing the verification by the EEA and the manufacturers of the data. The T,
# Va and Ve entries are set out in section 0.2 of the certificate of conformity or section 0.2.2. for
# the base vehicle in case of multistage vans (MSV).

# %%
current_columns = ['t','va','ve']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#     Row Number Field Name Definition Table Data Type Datatype in Dictionary  \
# 17          18          t      Type.          object            varchar(25)
# 19          20         va   Variant.          object            varchar(25)
# 20          21         ve   Version.          object            varchar(35)
#
#    Categorical / Quantitative % Null  Unique Counts Presence Indicator  \
# 17                Categorical  0.10%        23080.0            In Both
# 19                Categorical  0.27%        61500.0            In Both
# 20                Categorical  0.41%       165357.0            In Both
#
#    Unique Counts Post Cleaning Distribution Deleting? Why Deleting? Comments
# 17                        None         None      None          None     None
# 19                        None         None      None          None     None
# 20                        None         None      None          None     None

# %% [markdown]
# Type (T), Variant (Va) and Version (Ve) data analysis
# - good data availability
# - vehicle identifier, maybe useful for model grouping/ identification

# %%
for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'

    if current_column == 't':
        data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
        data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'Maybe'
        data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'May not be relevant for analyses.'
        data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further analysis needed to determine relevance.'
    elif current_column == 'va':
        data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
        data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'Maybe'
        data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'Might be too detailed or Manufacturer specific.'
        data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further cleaning may be needed based on domain knowledge'
    elif current_column == 've':
        data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
        data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'Maybe'
        data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'Might be too detailed or Manufacturer specific.'
        data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further cleaning may be needed based on domain knowledge'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#     Row Number Field Name Definition Table Data Type Datatype in Dictionary  \
# 17          18          t      Type.          object            varchar(25)
# 19          20         va   Variant.          object            varchar(25)
# 20          21         ve   Version.          object            varchar(35)
#
#    Categorical / Quantitative % Null  Unique Counts Presence Indicator  \
# 17                Categorical  0.10%        23080.0            In Both
# 19                Categorical  0.27%        61500.0            In Both
# 20                Categorical  0.41%       165357.0            In Both
#
#    Unique Counts Post Cleaning  \
# 17                        None
# 19                        None
# 20                        None
#
#                                          Distribution Deleting?  \
# 17         AU, AUV, 4L, 8R, 5F, X, 4G, F2A, E, A, ...     Maybe
# 19  GAC45CYVAX0, GAC45CYVBX0, GAC45CZCAX0, GAC45CZ...     Maybe
# 20  FM5FM5AF017N7MMON1VL61VR2, FM5FM5AF017N7MMON1V...     Maybe
#
#                                       Why Deleting?  \
# 17                May not be relevant for analyses.
# 19  Might be too detailed or Manufacturer specific.
# 20  Might be too detailed or Manufacturer specific.
#
#                                              Comments
# 17    Further analysis needed to determine relevance.
# 19  Further cleaning may be needed based on domain...
# 20  Further cleaning may be needed based on domain...

# %% [markdown]
# #####  19. Type approval number (TAN)

# %%
current_columns = ['tan']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
print('Type of Acquisition Value counts:')
display(eea_df['tan'].value_counts())
# Out:
#     Row Number Field Name             Definition Table Data Type  \
# 18          19        tan  Type approval number.          object
#
#    Datatype in Dictionary Categorical / Quantitative % Null  Unique Counts  \
# 18            varchar(50)                Categorical  0.86%        57599.0
#
#    Presence Indicator Unique Counts Post Cleaning Distribution Deleting?  \
# 18            In Both                        None         None      None
#
#    Why Deleting? Comments
# 18          None     None
# Type of Acquisition Value counts:
# tan
# E2*2001/116*0327*88    303254
# e2*2007/46*0070*39     284193
# e3*2007/46*0064*53     227331
# e2*2001/116*0327*83    216346
# E2*2007/46*0639*08     189893
#                         ...
# E1*2001/116*0106*18         1
# EL*2007/46*0539*14          1
# E2*2008/46*0405*04          1
# E1*2001/116*0301*02         1
# E8*IV18/858*HI3034          1
# Name: count, Length: 57599, dtype: int64

# %% [markdown]
# Type approval number (TAN) Data Analysis
# - good data avaialability
# - may not be relevant or usefull for the project

# %%
for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'

    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'Maybe'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'May not be relevant for analyses.'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further analysis needed to determine relevance.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#     Row Number Field Name             Definition Table Data Type  \
# 18          19        tan  Type approval number.          object
#
#    Datatype in Dictionary Categorical / Quantitative % Null  Unique Counts  \
# 18            varchar(50)                Categorical  0.86%        57599.0
#
#    Presence Indicator Unique Counts Post Cleaning  \
# 18            In Both                        None
#
#                                          Distribution Deleting?  \
# 18  e1*2007/46*0623*22, e1*2007/46*0623*21, e1*200...     Maybe
#
#                         Why Deleting?  \
# 18  May not be relevant for analyses.
#
#                                            Comments
# 18  Further analysis needed to determine relevance.

# %% [markdown]
# ##### 22.Verification factor and 26. Deviation Factor
#
#
# Deviation and verification factors are used in vehicle emissions testing to account for the difference between a vehicle's certified emissions during type approval and its actual real-world emissions.

# %%
current_columns = ['vf','de']

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])

# Filter the DataFrame where 'vf' and 'de' are not empty
filtered_df = eea_df[(eea_df['vf'].notna()) & (eea_df['de'].notna())]
# Group the data by 'year'and count the number of records
grouped_data = filtered_df.groupby(['year']).size().reset_index(name='Count')
grouped_data
# Out:
#     Row Number Field Name            Definition Table Data Type  \
# 21          22         vf  Verification factor.         float64
# 26          27         de     Deviation factor.         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 21                integer                Categorical  95.24%      None
# 26                  float               Quantitative  97.00%      None
#
#    Why Deleting? Comments  ...       std   min    25%    50%    75%  max  \
# 21          None     None  ...  0.084665   0.0    0.0    0.0    0.0  2.0
# 26          None     None  ...  0.021749 -0.24 -0.001  0.014  0.027  4.8
#
#    Unique Counts Post Cleaning Deleting? Why Deleting? Comments
# 21                        None      None          None     None
# 26                        None      None          None     None
#
# [2 rows x 23 columns]
#    year   Count
# 0  2018  550650
# 1  2019  821403
# 2  2020  883253

# %%
current_columns = ['de','vf']
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'Yes'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'Most records are empty.'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Low availablity. Values are limtied to years 2018-2020, the fields seem to be discontinued'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number Field Name            Definition Table Data Type  \
# 21          22         vf  Verification factor.         float64
# 26          27         de     Deviation factor.         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 21                integer                Categorical  95.24%       Yes
# 26                  float               Quantitative  97.00%       Yes
#
#               Why Deleting?  \
# 21  Most records are empty.
# 26  Most records are empty.
#
#                                              Comments  ...       std   min  \
# 21  Low availablity. Values are limtied to years 2...  ...  0.084665   0.0
# 26  Low availablity. Values are limtied to years 2...  ...  0.021749 -0.24
#
#       25%    50%    75%  max Unique Counts Post Cleaning Deleting?  \
# 21    0.0    0.0    0.0  2.0                        None       Yes
# 26 -0.001  0.014  0.027  4.8                        None       Yes
#
#               Why Deleting?                                           Comments
# 21  Most records are empty.  Low availablity. Values are limtied to years 2...
# 26  Most records are empty.  Low availablity. Values are limtied to years 2...
#
# [2 rows x 23 columns]

# %% [markdown]
# ##### 23. VFN

# %%
current_columns = ['vfn']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
display(eea_df[current_columns].value_counts())
# Out:
#     Row Number Field Name                             Definition  \
# 22          23        vfn  Vehicle family identification number.
#
#    Table Data Type Datatype in Dictionary Categorical / Quantitative  % Null  \
# 22          object            varchar(25)                Categorical  26.98%
#
#     Unique Counts Presence Indicator Unique Counts Post Cleaning Distribution  \
# 22        12964.0            In Both                        None         None
#
#    Deleting? Why Deleting? Comments
# 22      None          None     None
# vfn
# IP-0110-JT1-1               386069
# IP-HMH____MA5_5310-VR3-0    297517
# IP-HMR____MA5_1315-VF7-0    269429
# IP-03_312_0290-ZFA-1        255381
# IP-0153-JT1-1               242952
#                              ...
# IP-2019_146K9D-YV1-1             1
# IP-2019_224BMD-7JR-              1
# IP-2019_242-WDB-1                1
# IP-PQMIXXZ_A0_0526-WVW-1         1
# Â§                               1
# Name: count, Length: 12964, dtype: int64

# %%
for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'

    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'Maybe'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'May not be relevant for analyis.'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further analysis needed to determine relevance. Might help in model matching'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#     Row Number Field Name                             Definition  \
# 22          23        vfn  Vehicle family identification number.
#
#    Table Data Type Datatype in Dictionary Categorical / Quantitative  % Null  \
# 22          object            varchar(25)                Categorical  26.98%
#
#     Unique Counts Presence Indicator Unique Counts Post Cleaning  \
# 22        12964.0            In Both                        None
#
#                                          Distribution Deleting?  \
# 22  nan, IP-09-VSS-2018-0160, IP-04-YV1-2018-0034,...     Maybe
#
#                        Why Deleting?  \
# 22  May not be relevant for analyis.
#
#                                              Comments
# 22  Further analysis needed to determine relevance...

# %% [markdown]
# ##### 24. Year

# %%
current_columns = ['year']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])


# Count the number of rows per year
year_counts = eea_df['year'].value_counts().reset_index()
year_counts.columns = ['Year', 'Count']
year_counts = year_counts.sort_values(by='Year')

# Plot the number of records per year
plt.figure(figsize=(10, 5))
barplot = sns.barplot(
    x='Year', 
    y='Count', 
    data=year_counts
)

# Add value annotations on top of the bars
for i, row in enumerate(year_counts.itertuples()):
    plt.text(
        x=i,  # Use the index of the bar
        y=row.Count + 0.01 * max(year_counts['Count']),  # Slightly above the bar
        s=f"{row.Count:,}",  # Format the number with commas
        ha='center', 
        fontsize=10
    )

# Customize the chart
plt.title('Number of Records per Year', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Number of Records', fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.tight_layout()

# Show the plot
plt.show()
# Out:
#     Row Number Field Name       Definition Table Data Type  \
# 23          24       year  Reporting year.           int64
#
#    Datatype in Dictionary Categorical / Quantitative % Null  Unique Counts  \
# 23                integer                Categorical  0.00%           14.0
#
#    Presence Indicator Unique Counts Post Cleaning Distribution Deleting?  \
# 23            In Both                        None         None      None
#
#    Why Deleting? Comments
# 23          None     None

# %%
# Update Analysis fields
for current_column in current_columns:
# Update Analysis fields
    unique_values_list = eea_df[current_column].unique().tolist()
    # Limit the list to the first 10 items and convert to a string
    unique_values_string = ', '.join(map(str, unique_values_list[:10]))
    if len(unique_values_list) > 10:
        unique_values_string += ', ...'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] = unique_values_string
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Feature variable. No missing and rouge values'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), categorical_columns])
# Out:
#     Row Number Field Name       Definition Table Data Type  \
# 23          24       year  Reporting year.           int64
#
#    Datatype in Dictionary Categorical / Quantitative % Null  Unique Counts  \
# 23                integer                Categorical  0.00%           14.0
#
#    Presence Indicator Unique Counts Post Cleaning  \
# 23            In Both                        None
#
#                                          Distribution Deleting? Why Deleting?  \
# 23  2016, 2019, 2017, 2013, 2014, 2015, 2010, 2011...        No           N/A
#
#                                          Comments
# 23  Feature variable. No missing and rouge values

# %% [markdown]
# ##### 25-26. Axel width (steering and other)

# %%
current_columns = ['at1 (mm)', 'at2 (mm)']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])

# Iterate over the columns in current_columns
def plot_distribution_and_outlier(current_columns):
    for column in current_columns:
    # Create a 1x2 subplot layout for each column with smaller size
        fig, axes = plt.subplots(1, 2, figsize=(10, 4))

    # Plot the distribution of the column on the first subplot
        sns.histplot(eea_df[column], kde=True, bins=30, color='blue', ax=axes[0])
        axes[0].set_title(f'Distribution of {column}', fontsize=12)
        axes[0].set_xlabel(column, fontsize=10)
        axes[0].set_ylabel('Frequency', fontsize=10)
        axes[0].grid(axis='y', linestyle='--', alpha=0.7)

    # Plot a boxplot to visualize outliers on the second subplot
        sns.boxplot(x=eea_df[column], ax=axes[1])
        axes[1].set_title(f'Boxplot of {column} (Outlier Analysis)', fontsize=12)
        axes[1].set_xlabel(column, fontsize=10)
        axes[1].grid(axis='x', linestyle='--', alpha=0.7)

    # Adjust layout and show the plots
        plt.tight_layout()
        plt.show()

plot_distribution_and_outlier(current_columns)

display(eea_df[current_column].describe().to_json())
# Out:
#     Row Number Field Name                 Definition Table Data Type  \
# 24          25   at1 (mm)  Axle width steering axle.         float64
# 25          26   at2 (mm)     Axle width other axle.         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 24                integer               Quantitative  15.01%      None
# 25                integer               Quantitative  15.81%      None
#
#    Why Deleting? Comments  ...         std  min     25%     50%     75%  \
# 24          None     None  ...  124.924099  0.0  1509.0  1550.0  1580.0
# 25          None     None  ...   64.908789  0.0  1504.0  1547.0  1580.0
#
#         max Unique Counts Post Cleaning Deleting? Why Deleting? Comments
# 24  15851.0                        None      None          None     None
# 25  15830.0                        None      None          None     None
#
# [2 rows x 23 columns]
# '{"count":80377293,"unique":14,"top":"2019","freq":15499226}'

# %%
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Distribution'] =  eea_df[current_column].describe().to_json()
    display(eea_df[current_column].describe().to_json())
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further cleaning may be needed based on domain knowledge. Outliers present.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
# '{"count":68314348.0,"mean":1556.3831517795,"std":124.9240992161,"min":0.0,"25%":1509.0,"50%":1550.0,"75%":1580.0,"max":15851.0}'
# '{"count":67672263.0,"mean":1544.2143271461,"std":64.9087889344,"min":0.0,"25%":1504.0,"50%":1547.0,"75%":1580.0,"max":15830.0}'
#     Row Number Field Name                 Definition Table Data Type  \
# 24          25   at1 (mm)  Axle width steering axle.         float64
# 25          26   at2 (mm)     Axle width other axle.         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 24                integer               Quantitative  15.01%        No
# 25                integer               Quantitative  15.81%        No
#
#    Why Deleting?                                           Comments  ...  \
# 24           N/A  Further cleaning may be needed based on domain...  ...
# 25           N/A  Further cleaning may be needed based on domain...  ...
#
#            std  min     25%     50%     75%      max  \
# 24  124.924099  0.0  1509.0  1550.0  1580.0  15851.0
# 25   64.908789  0.0  1504.0  1547.0  1580.0  15830.0
#
#    Unique Counts Post Cleaning Deleting? Why Deleting?  \
# 24                        None        No           N/A
# 25                        None        No           N/A
#
#                                              Comments
# 24  Further cleaning may be needed based on domain...
# 25  Further cleaning may be needed based on domain...
#
# [2 rows x 23 columns]

# %% [markdown]
# ##### 28. Engine Capacity (ec (cm3))

# %%
current_columns = ['ec (cm3)']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
plot_distribution_and_outlier(current_columns)
# Out:
#     Row Number Field Name        Definition Table Data Type  \
# 27          28   ec (cm3)  Engine capacity.         float64
#
#    Datatype in Dictionary Categorical / Quantitative % Null Deleting?  \
# 27                integer               Quantitative  6.62%      None
#
#    Why Deleting? Comments  ...         std  min     25%     50%     75%  \
# 27          None     None  ...  518.299377  0.0  1199.0  1498.0  1968.0
#
#         max Unique Counts Post Cleaning Deleting? Why Deleting? Comments
# 27  84638.0                        None      None          None     None
#
# [1 rows x 23 columns]

# %%
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Feature. Further cleaning may be needed based on domain knowledge. Outliers present.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number Field Name        Definition Table Data Type  \
# 27          28   ec (cm3)  Engine capacity.         float64
#
#    Datatype in Dictionary Categorical / Quantitative % Null Deleting?  \
# 27                integer               Quantitative  6.62%        No
#
#    Why Deleting?                                           Comments  ...  \
# 27           N/A  Feature. Further cleaning may be needed based ...  ...
#
#            std  min     25%     50%     75%      max  \
# 27  518.299377  0.0  1199.0  1498.0  1968.0  84638.0
#
#    Unique Counts Post Cleaning Deleting? Why Deleting?  \
# 27                        None        No           N/A
#
#                                              Comments
# 27  Feature. Further cleaning may be needed based ...
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 29. Electic range (km)

# %%
current_columns = ['electric range (km)']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
plot_distribution_and_outlier(current_columns)
# Out:
#     Row Number           Field Name Definition Table Data Type  \
# 28          29  electric range (km)        NaN         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 28                    NaN               Quantitative  91.41%      None
#
#    Why Deleting? Comments  ...         std   min   25%    50%    75%    max  \
# 28          None     None  ...  188.942506  10.0  62.0  237.0  431.0  883.0
#
#    Unique Counts Post Cleaning Deleting? Why Deleting? Comments
# 28                        None      None          None     None
#
# [1 rows x 23 columns]

# %%
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Data looks clean. Low data avaialblity can be explained as data is only applicable for electric vehicles.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number           Field Name Definition Table Data Type  \
# 28          29  electric range (km)        NaN         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 28                    NaN               Quantitative  91.41%        No
#
#    Why Deleting?                                           Comments  ...  \
# 28           N/A  Data looks clean. Low data avaialblity can be ...  ...
#
#            std   min   25%    50%    75%    max Unique Counts Post Cleaning  \
# 28  188.942506  10.0  62.0  237.0  431.0  883.0                        None
#
#    Deleting? Why Deleting?                                           Comments
# 28        No           N/A  Data looks clean. Low data avaialblity can be ...
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 30. enedc (g/km)

# %%
current_columns = ['enedc (g/km)']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
plot_distribution_and_outlier(current_columns)
# Out:
#     Row Number    Field Name                      Definition Table Data Type  \
# 29          30  enedc (g/km)  Specific CO2 Emissions (NEDC).         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 29                integer               Quantitative  33.42%      None
#
#    Why Deleting? Comments  ...        std  min    25%    50%    75%    max  \
# 29          None     None  ...  42.503402  0.0  102.0  115.0  131.0  985.0
#
#    Unique Counts Post Cleaning Deleting? Why Deleting? Comments
# 29                        None      None          None     None
#
# [1 rows x 23 columns]

# %%
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Target variable. Further cleaning and merging with WLTP'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number    Field Name                      Definition Table Data Type  \
# 29          30  enedc (g/km)  Specific CO2 Emissions (NEDC).         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 29                integer               Quantitative  33.42%        No
#
#    Why Deleting?                                           Comments  ...  \
# 29           N/A  Target variable. Further cleaning and merging ...  ...
#
#           std  min    25%    50%    75%    max Unique Counts Post Cleaning  \
# 29  42.503402  0.0  102.0  115.0  131.0  985.0                        None
#
#    Deleting? Why Deleting?                                           Comments
# 29        No           N/A  Target variable. Further cleaning and merging ...
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 31 engine power ep (kw)

# %%
current_columns = ['ep (kw)']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
plot_distribution_and_outlier(current_columns)
# Out:
#     Row Number Field Name     Definition Table Data Type  \
# 30          31    ep (kw)  Engine power.         float64
#
#    Datatype in Dictionary Categorical / Quantitative % Null Deleting?  \
# 30                integer               Quantitative  8.03%      None
#
#    Why Deleting? Comments  ...        std  min   25%   50%    75%     max  \
# 30          None     None  ...  51.350621  0.0  72.0  92.0  112.0  1770.0
#
#    Unique Counts Post Cleaning Deleting? Why Deleting? Comments
# 30                        None      None          None     None
#
# [1 rows x 23 columns]

# %%
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further cleaning may be needed based on domain knowledge. Outliers present.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number Field Name     Definition Table Data Type  \
# 30          31    ep (kw)  Engine power.         float64
#
#    Datatype in Dictionary Categorical / Quantitative % Null Deleting?  \
# 30                integer               Quantitative  8.03%        No
#
#    Why Deleting?                                           Comments  ...  \
# 30           N/A  Further cleaning may be needed based on domain...  ...
#
#           std  min   25%   50%    75%     max Unique Counts Post Cleaning  \
# 30  51.350621  0.0  72.0  92.0  112.0  1770.0                        None
#
#    Deleting? Why Deleting?                                           Comments
# 30        No           N/A  Further cleaning may be needed based on domain...
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 32. ernedc (g/km)

# %%
current_columns = ['ernedc (g/km)']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
plot_distribution_and_outlier(current_columns)
# Out:
#     Row Number     Field Name  \
# 31          32  ernedc (g/km)
#
#                                            Definition Table Data Type  \
# 31  Emissions reduction through innovative technol...         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 31                  float               Quantitative  88.33%      None
#
#    Why Deleting? Comments  ...       std  min  25%  50%  75%  max  \
# 31          None     None  ...  0.755212  0.0  1.2  1.5  2.3  6.8
#
#    Unique Counts Post Cleaning Deleting? Why Deleting? Comments
# 31                        None      None          None     None
#
# [1 rows x 23 columns]

# %%
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'Maybe'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'Data availability is low'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further cleaning and analysis needed to determine relevance. Outliers present.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number     Field Name  \
# 31          32  ernedc (g/km)
#
#                                            Definition Table Data Type  \
# 31  Emissions reduction through innovative technol...         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 31                  float               Quantitative  88.33%     Maybe
#
#                Why Deleting?  \
# 31  Data availability is low
#
#                                              Comments  ...       std  min  \
# 31  Further cleaning and analysis needed to determ...  ...  0.755212  0.0
#
#     25%  50%  75%  max Unique Counts Post Cleaning Deleting?  \
# 31  1.2  1.5  2.3  6.8                        None     Maybe
#
#                Why Deleting?  \
# 31  Data availability is low
#
#                                              Comments
# 31  Further cleaning and analysis needed to determ...
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 33. erwwltp (g/km)

# %%
current_columns = ['erwltp (g/km)']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
plot_distribution_and_outlier(current_columns)
# Out:
#     Row Number     Field Name  \
# 32          33  erwltp (g/km)
#
#                                            Definition Table Data Type  \
# 32  Emissions reduction through innovative technol...         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 32                  float               Quantitative  76.40%      None
#
#    Why Deleting? Comments  ...       std  min   25%   50%   75%  max  \
# 32          None     None  ...  0.503496  0.0  1.03  1.58  1.94  4.6
#
#    Unique Counts Post Cleaning Deleting? Why Deleting? Comments
# 32                        None      None          None     None
#
# [1 rows x 23 columns]

# %%
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'Maybe'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'Data availability is low'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further analysis needed to determine relevance.Some outliers exist.'
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number     Field Name  \
# 32          33  erwltp (g/km)
#
#                                            Definition Table Data Type  \
# 32  Emissions reduction through innovative technol...         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 32                  float               Quantitative  76.40%     Maybe
#
#                Why Deleting?  \
# 32  Data availability is low
#
#                                              Comments  ...       std  min  \
# 32  Further analysis needed to determine relevance...  ...  0.503496  0.0
#
#      25%   50%   75%  max Unique Counts Post Cleaning Deleting?  \
# 32  1.03  1.58  1.94  4.6                        None     Maybe
#
#                Why Deleting?  \
# 32  Data availability is low
#
#                                              Comments
# 32  Further analysis needed to determine relevance...
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 34. ewltp (g/km)

# %%
current_columns = ['erwltp (g/km)']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
plot_distribution_and_outlier(current_columns)
# Out:
#     Row Number     Field Name  \
# 32          33  erwltp (g/km)
#
#                                            Definition Table Data Type  \
# 32  Emissions reduction through innovative technol...         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 32                  float               Quantitative  76.40%     Maybe
#
#                Why Deleting?  \
# 32  Data availability is low
#
#                                              Comments  ...       std  min  \
# 32  Further analysis needed to determine relevance...  ...  0.503496  0.0
#
#      25%   50%   75%  max Unique Counts Post Cleaning Deleting?  \
# 32  1.03  1.58  1.94  4.6                        None     Maybe
#
#                Why Deleting?  \
# 32  Data availability is low
#
#                                              Comments
# 32  Further analysis needed to determine relevance...
#
# [1 rows x 23 columns]

# %%
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Target Variable. Further cleaning and merging with NEDC. Outliers present.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number     Field Name  \
# 32          33  erwltp (g/km)
#
#                                            Definition Table Data Type  \
# 32  Emissions reduction through innovative technol...         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 32                  float               Quantitative  76.40%        No
#
#    Why Deleting?                                           Comments  ...  \
# 32           N/A  Target Variable. Further cleaning and merging ...  ...
#
#          std  min   25%   50%   75%  max Unique Counts Post Cleaning  \
# 32  0.503496  0.0  1.03  1.58  1.94  4.6                        None
#
#    Deleting? Why Deleting?                                           Comments
# 32        No           N/A  Target Variable. Further cleaning and merging ...
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 35. Version_file

# %%
current_columns = ['version_file']
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Only exists in data dictionary, not in data.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number    Field Name                            Definition  \
# 45          46  version_file  Internal versioning of deliverables.
#
#    Table Data Type Datatype in Dictionary Categorical / Quantitative % Null  \
# 45             NaN            varchar(10)                    Unknown    NaN
#
#    Deleting? Why Deleting?                                      Comments  ...  \
# 45       N/A           N/A  Only exists in data dictionary, not in data.  ...
#
#     std  min  25%  50%  75%  max Unique Counts Post Cleaning Deleting?  \
# 45  NaN  NaN  NaN  NaN  NaN  NaN                        None       N/A
#
#    Why Deleting?                                      Comments
# 45           N/A  Only exists in data dictionary, not in data.
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 36. Mass in running order m (kg)
# Mass in running order refers to the mass of the vehicle with bodywork in running order, i.e.
# the vehicle with its fuel tank(s) filled to at least 90 % of its or their capacity/ies, including the
# mass of the driver, of the fuel and liquids, fitted with the standard equipment in accordance
# with the manufacturer’s specifications and, when they are fitted, the mass of the bodywork,
# the cabin, the coupling and the spare wheel(s) as well as the tools (Regulation (EU) No
# 1230/2012).

# %%
current_columns = ['m (kg)']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
plot_distribution_and_outlier(current_columns)
# Out:
#     Row Number Field Name                                         Definition  \
# 35          36     m (kg)  Mass in running order Completed/complete vehic...
#
#    Table Data Type Datatype in Dictionary Categorical / Quantitative % Null  \
# 35         float64                integer               Quantitative  0.01%
#
#    Deleting? Why Deleting? Comments  ...         std  min     25%     50%  \
# 35      None          None     None  ...  322.105915  1.0  1229.0  1395.0
#
#        75%     max Unique Counts Post Cleaning Deleting? Why Deleting?  \
# 35  1616.0  9825.0                        None      None          None
#
#    Comments
# 35     None
#
# [1 rows x 23 columns]

# %%
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further cleaning may be needed based on domain knowledge. Outliers present.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number Field Name                                         Definition  \
# 35          36     m (kg)  Mass in running order Completed/complete vehic...
#
#    Table Data Type Datatype in Dictionary Categorical / Quantitative % Null  \
# 35         float64                integer               Quantitative  0.01%
#
#    Deleting? Why Deleting?                                           Comments  \
# 35        No           N/A  Further cleaning may be needed based on domain...
#
#     ...         std  min     25%     50%     75%     max  \
# 35  ...  322.105915  1.0  1229.0  1395.0  1616.0  9825.0
#
#    Unique Counts Post Cleaning Deleting? Why Deleting?  \
# 35                        None        No           N/A
#
#                                              Comments
# 35  Further cleaning may be needed based on domain...
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 37.  WLTP Test Mass mt

# %%
current_columns = ['mt']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
plot_distribution_and_outlier(current_columns)
# Out:
#     Row Number Field Name       Definition Table Data Type  \
# 36          37         mt  WLTP test mass.         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 36                integer               Quantitative  24.69%      None
#
#    Why Deleting? Comments  ...         std    min     25%     50%     75%  \
# 36          None     None  ...  347.648153  135.0  1350.0  1542.0  1782.0
#
#        max Unique Counts Post Cleaning Deleting? Why Deleting? Comments
# 36  6542.0                        None      None          None     None
#
# [1 rows x 23 columns]

# %%
display(eea_df[current_column].describe().to_json())

for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further cleaning may be needed based on domain knowledge. Outliers present. Can be correlated with m (kg)'
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
# '{"count":80366778.0,"mean":1456.5010988247,"std":322.105915386,"min":1.0,"25%":1229.0,"50%":1395.0,"75%":1616.0,"max":9825.0}'
#     Row Number Field Name       Definition Table Data Type  \
# 36          37         mt  WLTP test mass.         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 36                integer               Quantitative  24.69%        No
#
#    Why Deleting?                                           Comments  ...  \
# 36           N/A  Further cleaning may be needed based on domain...  ...
#
#            std    min     25%     50%     75%     max  \
# 36  347.648153  135.0  1350.0  1542.0  1782.0  6542.0
#
#    Unique Counts Post Cleaning Deleting? Why Deleting?  \
# 36                        None        No           N/A
#
#                                              Comments
# 36  Further cleaning may be needed based on domain...
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 38. Registrations (r)
# Following the introduction of the VIN based data monitoring, the data entry for this field will
# by default be '1' since each vehicle will be reported separately.

# %%
current_columns = ['r']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
plot_distribution_and_outlier(current_columns)
# Out:
#     Row Number Field Name                Definition Table Data Type  \
# 37          38          r  Total new registrations.           int64
#
#    Datatype in Dictionary Categorical / Quantitative % Null Deleting?  \
# 37                integer               Quantitative  0.00%      None
#
#    Why Deleting? Comments  ...       std  min  25%  50%  75%      max  \
# 37          None     None  ...  47.28428  1.0  1.0  1.0  1.0  59092.0
#
#    Unique Counts Post Cleaning Deleting? Why Deleting? Comments
# 37                        None      None          None     None
#
# [1 rows x 23 columns]

# %% [markdown]
# Registrations (r) data analysis
# - optimal data availability
# - no further cleanup needed

# %%
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Used as multiplyer/averaging. Most values is 1'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number Field Name                Definition Table Data Type  \
# 37          38          r  Total new registrations.           int64
#
#    Datatype in Dictionary Categorical / Quantitative % Null Deleting?  \
# 37                integer               Quantitative  0.00%        No
#
#    Why Deleting?                                        Comments  ...  \
# 37           N/A  Used as multiplyer/averaging. Most values is 1  ...
#
#          std  min  25%  50%  75%      max Unique Counts Post Cleaning  \
# 37  47.28428  1.0  1.0  1.0  1.0  59092.0                        None
#
#    Deleting? Why Deleting?                                        Comments
# 37        No           N/A  Used as multiplyer/averaging. Most values is 1
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 39. Wheel base W (mm)

# %%
current_columns = ['w (mm)']

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
plot_distribution_and_outlier(current_columns)
# Out:
#     Row Number Field Name   Definition Table Data Type Datatype in Dictionary  \
# 38          39     w (mm)  Wheel Base.         float64                integer
#
#    Categorical / Quantitative  % Null Deleting? Why Deleting? Comments  ...  \
# 38               Quantitative  13.71%      None          None     None  ...
#
#            std  min     25%     50%     75%     max  \
# 38  206.974511  0.0  2552.0  2640.0  2720.0  6100.0
#
#    Unique Counts Post Cleaning Deleting? Why Deleting? Comments
# 38                        None      None          None     None
#
# [1 rows x 23 columns]

# %%
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further cleaning and analysis needed based on domain knowledge. Outliers present.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number Field Name   Definition Table Data Type Datatype in Dictionary  \
# 38          39     w (mm)  Wheel Base.         float64                integer
#
#    Categorical / Quantitative  % Null Deleting? Why Deleting?  \
# 38               Quantitative  13.71%        No           N/A
#
#                                              Comments  ...         std  min  \
# 38  Further cleaning and analysis needed based on ...  ...  206.974511  0.0
#
#        25%     50%     75%     max Unique Counts Post Cleaning Deleting?  \
# 38  2552.0  2640.0  2720.0  6100.0                        None        No
#
#    Why Deleting?                                           Comments
# 38           N/A  Further cleaning and analysis needed based on ...
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 40. Electic energy consumption z (wh/km)

# %%
current_columns = ['z (wh/km)']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
plot_distribution_and_outlier(current_columns)
# Out:
#     Row Number Field Name                    Definition Table Data Type  \
# 39          40  z (wh/km)  Electric energy consumption.         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 39                integer               Quantitative  89.96%      None
#
#    Why Deleting? Comments  ...        std  min    25%    50%    75%     max  \
# 39          None     None  ...  39.979303  1.0  153.0  165.0  181.0  1754.0
#
#    Unique Counts Post Cleaning Deleting? Why Deleting? Comments
# 39                        None      None          None     None
#
# [1 rows x 23 columns]

# %%
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further cleaning and analysis needed based on domain knowledge. Outliers present.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number Field Name                    Definition Table Data Type  \
# 39          40  z (wh/km)  Electric energy consumption.         float64
#
#    Datatype in Dictionary Categorical / Quantitative  % Null Deleting?  \
# 39                integer               Quantitative  89.96%        No
#
#    Why Deleting?                                           Comments  ...  \
# 39           N/A  Further cleaning and analysis needed based on ...  ...
#
#           std  min    25%    50%    75%     max Unique Counts Post Cleaning  \
# 39  39.979303  1.0  153.0  165.0  181.0  1754.0                        None
#
#    Deleting? Why Deleting?                                           Comments
# 39        No           N/A  Further cleaning and analysis needed based on ...
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 41. Emission reduction through innovaltive technology e (g/km)
# Depricated value, only exists in data dictionary

# %%
current_columns = ['e (g/km)']
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Does not exist in data, only in data dictionary.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number Field Name                                         Definition  \
# 41          42   e (g/km)  Specific CO2 Emission. Deprecated value, only ...
#
#    Table Data Type Datatype in Dictionary Categorical / Quantitative % Null  \
# 41             NaN                  float                    Unknown    NaN
#
#    Deleting? Why Deleting?                                          Comments  \
# 41       N/A           N/A  Does not exist in data, only in data dictionary.
#
#     ...  std  min  25%  50%  75%  max Unique Counts Post Cleaning Deleting?  \
# 41  ...  NaN  NaN  NaN  NaN  NaN  NaN                        None       N/A
#
#    Why Deleting?                                          Comments
# 41           N/A  Does not exist in data, only in data dictionary.
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 42. Emission rediction through innovative technology er (g/km)

# %%
current_columns = ['er (g/km)']
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Does not exist in data, only in data dictionary.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number Field Name                                         Definition  \
# 41          42   e (g/km)  Specific CO2 Emission. Deprecated value, only ...
#
#    Table Data Type Datatype in Dictionary Categorical / Quantitative % Null  \
# 41             NaN                  float                    Unknown    NaN
#
#    Deleting? Why Deleting?                                          Comments  \
# 41       N/A           N/A  Does not exist in data, only in data dictionary.
#
#     ...  std  min  25%  50%  75%  max Unique Counts Post Cleaning Deleting?  \
# 41  ...  NaN  NaN  NaN  NaN  NaN  NaN                        None       N/A
#
#    Why Deleting?                                          Comments
# 41           N/A  Does not exist in data, only in data dictionary.
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 43. version_file

# %%
current_columns = ['version_file']
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Does not exist in data, only in data dictionary.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number    Field Name                            Definition  \
# 45          46  version_file  Internal versioning of deliverables.
#
#    Table Data Type Datatype in Dictionary Categorical / Quantitative % Null  \
# 45             NaN            varchar(10)                    Unknown    NaN
#
#    Deleting? Why Deleting?                                          Comments  \
# 45       N/A           N/A  Does not exist in data, only in data dictionary.
#
#     ...  std  min  25%  50%  75%  max Unique Counts Post Cleaning Deleting?  \
# 45  ...  NaN  NaN  NaN  NaN  NaN  NaN                        None       N/A
#
#    Why Deleting?                                          Comments
# 45           N/A  Does not exist in data, only in data dictionary.
#
# [1 rows x 23 columns]

# %% [markdown]
# ##### 44. Mass in running order m (kg)
# Mass in running order (m) is used for the calculation of the specific emission target of a
# manufacturer.
# 16
# Mass in running order refers to the mass of the vehicle with bodywork in running order, i.e.
# the vehicle with its fuel tank(s) filled to at least 90 % of its or their capacity/ies, including the
# mass of the driver, of the fuel and liquids, fitted with the standard equipment in accordance
# with the manufacturer’s specifications and, when they are fitted, the mass of the bodywork,
# the cabin, the coupling and the spare wheel(s) as well as the tools (Regulation (EU) No
# 1230/2012).

# %%
current_columns = ['m (kg)']
display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
plot_distribution_and_outlier(current_columns)
# Out:
#     Row Number Field Name                                         Definition  \
# 35          36     m (kg)  Mass in running order Completed/complete vehic...
#
#    Table Data Type Datatype in Dictionary Categorical / Quantitative % Null  \
# 35         float64                integer               Quantitative  0.01%
#
#    Deleting? Why Deleting?                                           Comments  \
# 35        No           N/A  Further cleaning may be needed based on domain...
#
#     ...         std  min     25%     50%     75%     max  \
# 35  ...  322.105915  1.0  1229.0  1395.0  1616.0  9825.0
#
#    Unique Counts Post Cleaning Deleting? Why Deleting?  \
# 35                        None        No           N/A
#
#                                              Comments
# 35  Further cleaning may be needed based on domain...
#
# [1 rows x 23 columns]

# %%
for current_column in current_columns:
# Update Analysis fields
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Deleting?'] = 'No'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Why Deleting?'] = 'N/A'
    data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'] == current_column, 'Comments'] = 'Further cleaning may be needed based on domain knowledge. Outliers present.'

display(data_profile_and_dictionary.loc[data_profile_and_dictionary['Field Name'].isin(current_columns), noncategorical_columns])
# Out:
#     Row Number Field Name                                         Definition  \
# 35          36     m (kg)  Mass in running order Completed/complete vehic...
#
#    Table Data Type Datatype in Dictionary Categorical / Quantitative % Null  \
# 35         float64                integer               Quantitative  0.01%
#
#    Deleting? Why Deleting?                                           Comments  \
# 35        No           N/A  Further cleaning may be needed based on domain...
#
#     ...         std  min     25%     50%     75%     max  \
# 35  ...  322.105915  1.0  1229.0  1395.0  1616.0  9825.0
#
#    Unique Counts Post Cleaning Deleting? Why Deleting?  \
# 35                        None        No           N/A
#
#                                              Comments
# 35  Further cleaning may be needed based on domain...
#
# [1 rows x 23 columns]

# %% [markdown]
# #### Individual Field Analysis Summary

# %%
# Select only the specified fields
fields_to_display = [
    'Row Number', 'Field Name', 'Missing Percentage', 'Unique Counts', 
    'Table Data Type', 'Definition', 'Datatype', 'Presence Indicator', 'Categorical / Quantitative',
    'Distribution', 'Deleting?', 'Why Deleting?', 'Comments'
]
#filtered_data = data_profile_and_dictionary[fields_to_display]
filtered_data = data_profile_and_dictionary

# Adjust column widths for Distribution and Comments
column_widths = {col: '5%' for col in fields_to_display}
column_widths['Distribution'] = '40%'
column_widths['Comments'] = '20%'

# Define the highlighting function
def highlight_deleted_rows(row):
    if row['Deleting?'] in ['Yes', 'N/A']:
        return ['background-color: grey'] * len(row)
    return [''] * len(row)

# Apply the highlighting function to the filtered DataFrame
styled_table = filtered_data.style.apply(highlight_deleted_rows, axis=1).hide(axis="index")

# Convert the styled DataFrame to HTML
html_table = styled_table.to_html(escape=False)

# Add CSS for column widths
wrapped_html = f"""
<style>
    table {{ table-layout: fixed; width: 100%; }}
    td, th {{ word-wrap: break-word; white-space: pre-wrap; vertical-align: top; }}
    {' '.join([f'th:nth-child({i+1}), td:nth-child({i+1}) {{ width: {column_widths[col]}; }}' for i, col in enumerate(fields_to_display)])}
</style>
{html_table}
"""

# Define the highlighting function
def highlight_deleted_rows(row):
    if row['Deleting?'] in ['Yes', 'N/A']:
        return ['background-color: grey'] * len(row)
    return [''] * len(row)

# Apply the highlighting function to the filtered DataFrame
styled_table = filtered_data.style.apply(highlight_deleted_rows, axis=1).hide(axis="index")

# Convert the styled DataFrame to HTML
html_table = styled_table.to_html(escape=False)

# Add CSS to wrap text and adjust cell height
wrapped_html = f"""
<style>
    table {{ table-layout: fixed; width: 100%; }}
    td, th {{ word-wrap: break-word; white-space: pre-wrap; vertical-align: top; }}
</style>
{html_table}
"""

# Display the styled table
display(HTML(wrapped_html))
# Out:
# <style>
#     table { table-layout: fixed; width: 100%; }
#     td, th { word-wrap: break-word; white-space: pre-wrap; vertical-align: top; }
# </style>
# <style type="text/css">
# #T_cbe6b_row3_col0, #T_cbe6b_row3_col1, #T_cbe6b_row3_col2, #T_cbe6b_row3_col3, #T_cbe6b_row3_col4, #T_cbe6b_row3_col5, #T_cbe6b_row3_col6, #T_cbe6b_row3_col7, #T_cbe6b_row3_col8, #T_cbe6b_row3_col9, #T_cbe6b_row3_col10, #T_cbe6b_row3_col11, #T_cbe6b_row3_col12, #T_cbe6b_row3_col13, #T_cbe6b_row3_col14, #T_cbe6b_row3_col15, #T_cbe6b_row3_col16, #T_cbe6b_row3_col17, #T_cbe6b_row3_col18, #T_cbe6b_row3_col19, #T_cbe6b_row3_col20, #T_cbe6b_row3_col21, #T_cbe6b_row4_col0, #T_cbe6b_row4_col1, #T_cbe6b_row4_col2, #T_cbe6b_row4_col3, #T_cbe6b_row4_col4, #T_cbe6b_row4_col5, #T_cbe6b_row4_col6, #T_cbe6b_row4_col7, #T_cbe6b_row4_col8, #T_cbe6b_row4_col9, #T_cbe6b_row4_col10, #T_cbe6b_row4_col11, #T_cbe6b_row4_col12, #T_cbe6b_row4_col13, #T_cbe6b_row4_col14, #T_cbe6b_row4_col15, #T_cbe6b_row4_col16, #T_cbe6b_row4_col17, #T_cbe6b_row4_col18, #T_cbe6b_row4_col19, #T_cbe6b_row4_col20, #T_cbe6b_row4_col21, #T_cbe6b_row5_col0, #T_cbe6b_row5_col1, #T_cbe6b_row5_col2, #T_cbe6b_row5_col3, #T_cbe6b_row5_col4, #T_cbe6b_row5_col5, #T_cbe6b_row5_col6, #T_cbe6b_row5_col7, #T_cbe6b_row5_col8, #T_cbe6b_row5_col9, #T_cbe6b_row5_col10, #T_cbe6b_row5_col11, #T_cbe6b_row5_col12, #T_cbe6b_row5_col13, #T_cbe6b_row5_col14, #T_cbe6b_row5_col15, #T_cbe6b_row5_col16, #T_cbe6b_row5_col17, #T_cbe6b_row5_col18, #T_cbe6b_row5_col19, #T_cbe6b_row5_col20, #T_cbe6b_row5_col21, #T_cbe6b_row8_col0, #T_cbe6b_row8_col1, #T_cbe6b_row8_col2, #T_cbe6b_row8_col3, #T_cbe6b_row8_col4, #T_cbe6b_row8_col5, #T_cbe6b_row8_col6, #T_cbe6b_row8_col7, #T_cbe6b_row8_col8, #T_cbe6b_row8_col9, #T_cbe6b_row8_col10, #T_cbe6b_row8_col11, #T_cbe6b_row8_col12, #T_cbe6b_row8_col13, #T_cbe6b_row8_col14, #T_cbe6b_row8_col15, #T_cbe6b_row8_col16, #T_cbe6b_row8_col17, #T_cbe6b_row8_col18, #T_cbe6b_row8_col19, #T_cbe6b_row8_col20, #T_cbe6b_row8_col21, #T_cbe6b_row15_col0, #T_cbe6b_row15_col1, #T_cbe6b_row15_col2, #T_cbe6b_row15_col3, #T_cbe6b_row15_col4, #T_cbe6b_row15_col5, #T_cbe6b_row15_col6, #T_cbe6b_row15_col7, #T_cbe6b_row15_col8, #T_cbe6b_row15_col9, #T_cbe6b_row15_col10, #T_cbe6b_row15_col11, #T_cbe6b_row15_col12, #T_cbe6b_row15_col13, #T_cbe6b_row15_col14, #T_cbe6b_row15_col15, #T_cbe6b_row15_col16, #T_cbe6b_row15_col17, #T_cbe6b_row15_col18, #T_cbe6b_row15_col19, #T_cbe6b_row15_col20, #T_cbe6b_row15_col21, #T_cbe6b_row16_col0, #T_cbe6b_row16_col1, #T_cbe6b_row16_col2, #T_cbe6b_row16_col3, #T_cbe6b_row16_col4, #T_cbe6b_row16_col5, #T_cbe6b_row16_col6, #T_cbe6b_row16_col7, #T_cbe6b_row16_col8, #T_cbe6b_row16_col9, #T_cbe6b_row16_col10, #T_cbe6b_row16_col11, #T_cbe6b_row16_col12, #T_cbe6b_row16_col13, #T_cbe6b_row16_col14, #T_cbe6b_row16_col15, #T_cbe6b_row16_col16, #T_cbe6b_row16_col17, #T_cbe6b_row16_col18, #T_cbe6b_row16_col19, #T_cbe6b_row16_col20, #T_cbe6b_row16_col21, #T_cbe6b_row21_col0, #T_cbe6b_row21_col1, #T_cbe6b_row21_col2, #T_cbe6b_row21_col3, #T_cbe6b_row21_col4, #T_cbe6b_row21_col5, #T_cbe6b_row21_col6, #T_cbe6b_row21_col7, #T_cbe6b_row21_col8, #T_cbe6b_row21_col9, #T_cbe6b_row21_col10, #T_cbe6b_row21_col11, #T_cbe6b_row21_col12, #T_cbe6b_row21_col13, #T_cbe6b_row21_col14, #T_cbe6b_row21_col15, #T_cbe6b_row21_col16, #T_cbe6b_row21_col17, #T_cbe6b_row21_col18, #T_cbe6b_row21_col19, #T_cbe6b_row21_col20, #T_cbe6b_row21_col21, #T_cbe6b_row26_col0, #T_cbe6b_row26_col1, #T_cbe6b_row26_col2, #T_cbe6b_row26_col3, #T_cbe6b_row26_col4, #T_cbe6b_row26_col5, #T_cbe6b_row26_col6, #T_cbe6b_row26_col7, #T_cbe6b_row26_col8, #T_cbe6b_row26_col9, #T_cbe6b_row26_col10, #T_cbe6b_row26_col11, #T_cbe6b_row26_col12, #T_cbe6b_row26_col13, #T_cbe6b_row26_col14, #T_cbe6b_row26_col15, #T_cbe6b_row26_col16, #T_cbe6b_row26_col17, #T_cbe6b_row26_col18, #T_cbe6b_row26_col19, #T_cbe6b_row26_col20, #T_cbe6b_row26_col21, #T_cbe6b_row41_col0, #T_cbe6b_row41_col1, #T_cbe6b_row41_col2, #T_cbe6b_row41_col3, #T_cbe6b_row41_col4, #T_cbe6b_row41_col5, #T_cbe6b_row41_col6, #T_cbe6b_row41_col7, #T_cbe6b_row41_col8, #T_cbe6b_row41_col9, #T_cbe6b_row41_col10, #T_cbe6b_row41_col11, #T_cbe6b_row41_col12, #T_cbe6b_row41_col13 ...
#   background-color: grey;
# }
# </style>
# <table id="T_cbe6b">
#   <thead>
#     <tr>
#       <th id="T_cbe6b_level0_col0" class="col_heading level0 col0" >Row Number</th>
#       <th id="T_cbe6b_level0_col1" class="col_heading level0 col1" >Field Name</th>
#       <th id="T_cbe6b_level0_col2" class="col_heading level0 col2" >Definition</th>
#       <th id="T_cbe6b_level0_col3" class="col_heading level0 col3" >Table Data Type</th>
#       <th id="T_cbe6b_level0_col4" class="col_heading level0 col4" >Datatype in Dictionary</th>
#       <th id="T_cbe6b_level0_col5" class="col_heading level0 col5" >Categorical / Quantitative</th>
#       <th id="T_cbe6b_level0_col6" class="col_heading level0 col6" >% Null</th>
#       <th id="T_cbe6b_level0_col7" class="col_heading level0 col7" >Unique Counts</th>
#       <th id="T_cbe6b_level0_col8" class="col_heading level0 col8" >Unique Counts Post Cleaning</th>
#       <th id="T_cbe6b_level0_col9" class="col_heading level0 col9" >Presence Indicator</th>
#       <th id="T_cbe6b_level0_col10" class="col_heading level0 col10" >count</th>
#       <th id="T_cbe6b_level0_col11" class="col_heading level0 col11" >mean</th>
#       <th id="T_cbe6b_level0_col12" class="col_heading level0 col12" >std</th>
#       <th id="T_cbe6b_level0_col13" class="col_heading level0 col13" >min</th>
#       <th id="T_cbe6b_level0_col14" class="col_heading level0 col14" >25%</th>
#       <th id="T_cbe6b_level0_col15" class="col_heading level0 col15" >50%</th>
#       <th id="T_cbe6b_level0_col16" class="col_heading level0 col16" >75%</th>
#       <th id="T_cbe6b_level0_col17" class="col_heading level0 col17" >max</th>
#       <th id="T_cbe6b_level0_col18" class="col_heading level0 col18" >Distribution</th>
#       <th id="T_cbe6b_level0_col19" class="col_heading level0 col19" >Deleting?</th>
#       <th id="T_cbe6b_level0_col20" class="col_heading level0 col20" >Why Deleting?</th>
#       <th id="T_cbe6b_level0_col21" class="col_heading level0 col21" >Comments</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cbe6b_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_cbe6b_row0_col1" class="data row0 col1" >cn</td>
#       <td id="T_cbe6b_row0_col2" class="data row0 col2" >Commercial name.</td>
#       <td id="T_cbe6b_row0_col3" class="data row0 col3" >object</td>
#       <td id="T_cbe6b_row0_col4" class="data row0 col4" >varchar(50)</td>
#       <td id="T_cbe6b_row0_col5" class="data row0 col5" >Categorical</td>
#       <td id="T_cbe6b_row0_col6" class="data row0 col6" >0.19%</td>
#       <td id="T_cbe6b_row0_col7" class="data row0 col7" >75100.000000</td>
#       <td id="T_cbe6b_row0_col8" class="data row0 col8" >None</td>
#       <td id="T_cbe6b_row0_col9" class="data row0 col9" >In Both</td>
#       <td id="T_cbe6b_row0_col10" class="data row0 col10" >80221593</td>
#       <td id="T_cbe6b_row0_col11" class="data row0 col11" >nan</td>
#       <td id="T_cbe6b_row0_col12" class="data row0 col12" >nan</td>
#       <td id="T_cbe6b_row0_col13" class="data row0 col13" >nan</td>
#       <td id="T_cbe6b_row0_col14" class="data row0 col14" >nan</td>
#       <td id="T_cbe6b_row0_col15" class="data row0 col15" >nan</td>
#       <td id="T_cbe6b_row0_col16" class="data row0 col16" >nan

# %% [markdown]
# ### Visualizations and Statistics
